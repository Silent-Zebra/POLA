# %% [markdown]
# <a href="https://colab.research.google.com/github/Silent-Zebra/marl-nagents/blob/master/POLA_Data_for_Figure_Showing_Single_Update_with_Different_Parameterizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LOLA update with custom param 1 (size 2 neural net)
# !python LOLA_exact.py --n_agents 2 --using_nn --nn_hidden_size 2 --custom_param 1 --print_every 1 --repeats 1 --num_epochs 1 --init_state_representation 2  --set_seed --seed 1 --lr_policies_inner 0.2 --lr_policies_outer .05 --actual_update --base_cf_no_scale 1.33
# Out:
# Number of agents: 2
# Contribution factor: 1.33
# Scaled contribution factor? False
# Exact Gradients
# Actual Update LOLA
# lr_policies_outer: tensor([0.0500, 0.0500])
# lr_policies_inner: tensor([0.2000, 0.2000])
# Starting Policies:
# Policy 1
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SqueezeBackward1>)
# Epoch: 1
# Time Elapsed: 0.2 seconds
# Discounted Rewards: tensor([3.6877, 3.6877])
# Max Avg Coop Payout (Infinite Horizon): 8.250
# Policy 1
# tensor([0.3908, 0.5113, 0.4350, 0.4683, 0.4479], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.3908, 0.4350, 0.5113, 0.4683, 0.4479], grad_fn=<SqueezeBackward1>)

# %%
# LOLA update with custom param 4 (size 2 neural net)
# !pip install higher
# !python LOLA_exact.py --n_agents 2 --using_nn --nn_hidden_size 2 --custom_param 4 --print_every 1 --repeats 1 --num_epochs 1 --init_state_representation 2  --set_seed --seed 1 --lr_policies_inner 0.2 --lr_policies_outer .05 --actual_update --base_cf_no_scale 1.33
# Out:
# Requirement already satisfied: higher in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from higher) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->higher) (4.2.0)
# Number of agents: 2
# Contribution factor: 1.33
# Scaled contribution factor? False
# Exact Gradients
# Actual Update LOLA
# lr_policies_outer: tensor([0.0500, 0.0500])
# lr_policies_inner: tensor([0.2000, 0.2000])
# Starting Policies:
# Policy 1
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SqueezeBackward1>)
# Epoch: 1
# Time Elapsed: 0.2 seconds
# Discounted Rewards: tensor([3.7305, 3.4854])
# Max Avg Coop Payout (Infinite Horizon): 8.250
# Policy 1
# tensor([0.4318, 0.4418, 0.4204, 0.4352, 0.4375], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.4298, 0.4298, 0.4575, 0.4575, 0.4531], grad_fn=<SqueezeBackward1>)

# %%
# Tabular LOLA
# !python LOLA_exact.py --n_agents 2 --print_every 1 --repeats 1 --num_epochs 1 --init_state_representation 2  --std 0  --lr_policies_inner 1 --lr_policies_outer .2 --set_seed --seed 1 --actual_update --base_cf_no_scale 1.33
# Out:
# Number of agents: 2
# Contribution factor: 1.33
# Scaled contribution factor? False
# Exact Gradients
# Actual Update LOLA
# lr_policies_outer: tensor([0.2000, 0.2000])
# lr_policies_inner: tensor([1., 1.])
# Starting Policies:
# Policy 1
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# Epoch: 1
# Time Elapsed: 0.1 seconds
# Discounted Rewards: tensor([3.9139, 3.9139])
# Max Avg Coop Payout (Infinite Horizon): 8.250
# Policy 1
# tensor([0.4465, 0.5035, 0.4465, 0.5035, 0.4958], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4465, 0.4465, 0.5035, 0.5035, 0.4958], grad_fn=<SigmoidBackward0>)

# %%
# POLA update with custom param 1 (size 2 neural net)
# !python LOLA_exact.py --n_agents 2 --using_nn --nn_hidden_size 2 --custom_param 1 --print_every 1 --repeats 1 --num_epochs 1 --init_state_representation 2  --set_seed --seed 1 --lr_policies_inner 0.003 --lr_policies_outer .003 --actual_update --base_cf_no_scale 1.33 --inner_exact_prox --inner_beta 2 --outer_exact_prox --outer_beta 5 --print_prox_loops_info
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor([0.4254, 0.4406, 0.4196, 0.4403, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1896, 0.3530, 0.5715, 0.6166, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0.3278, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1896, 0.3530, 0.5715, 0.6166, 0.4783])
# Curr pol
# tensor([0.1898, 0.3532, 0.5713, 0.6160, 0.4783])
# Iter:
# 607
# Inner prox iters used: 1
# Policy 1
# tensor([0.4254, 0.4406, 0.4196, 0.4403, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1898, 0.3532, 0.5713, 0.6160, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4254, 0.4406, 0.4196, 0.4403, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1898, 0.3532, 0.5713, 0.6160, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0.3270, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1898, 0.3532, 0.5713, 0.6160, 0.4783])
# Curr pol
# tensor([0.1899, 0.3533, 0.5711, 0.6154, 0.4783])
# Iter:
# 608
# Inner prox iters used: 2
# Policy 1
# tensor([0.4253, 0.4406, 0.4196, 0.4403, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1899, 0.3533, 0.5711, 0.6154, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4253, 0.4406, 0.4196, 0.4403, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1899, 0.3533, 0.5711, 0.6154, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0.3264, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1899, 0.3533, 0.5711, 0.6154, 0.4783])
# Curr pol
# tensor([0.1899, 0.3533, 0.5711, 0.6150, 0.4783])
# Iter:
# 609
# Inner prox iters used: 3
# Policy 1
# tensor([0.4252, 0.4406, 0.4196, 0.4402, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1899, 0.3533, 0.5711, 0.6150, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4252, 0.4406, 0.4196, 0.4402, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1899, 0.3533, 0.5711, 0.6150, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0.3260, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1899, 0.3533, 0.5711, 0.6150, 0.4783])
# Curr pol
# tensor([0.1900, 0.3534, 0.5709, 0.6145, 0.4783])
# Iter:
# 610
# Inner prox iters used: 11
# Policy 1
# tensor([0.4247, 0.4404, 0.4194, 0.4400, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1900, 0.3534, 0.5709, 0.6145, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4247, 0.4404, 0.4194, 0.4400, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1900, 0.3534, 0.5709, 0.6145, 0.4783], grad_fn=<SqueezeBackward1>)
# tensor(0.3255, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1900, 0.3534, 0.5709, 0.6145, 0.4783])
# Curr pol
# tensor([0.1901, 0.3535, 0.5709, 0.6142, 0.4784])
# Iter:
# 611
# Inner prox iters used: 34
# Policy 1
# tensor([0.4236, 0.4400, 0.4190, 0.4396, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1901, 0.3535, 0.5709, 0.6142, 0.4784], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4236, 0.4400, 0.4190, 0.4396, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1901, 0.3535, 0.5709, 0.6142, 0.4784], grad_fn=<SqueezeBackward1>)
# tensor(0.3251, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1901, 0.3535, 0.5709, 0.6142, 0.4784])
# Curr pol
# tensor([0.1902, 0.3536, 0.5708, 0.6141, 0.4785])
# Iter:
# 612
# Inner prox iters used: 9
# Policy 1
# tensor([0.4234, 0.4400, 0.4189, 0.4396, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1902, 0.3536, 0.5708, 0.6141, 0.4785], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4234, 0.4400, 0.4189, 0.4396, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1902, 0.3536, 0.5708, 0.6141, 0.4785], grad_fn=<SqueezeBackward1>)
# tensor(0.3248, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1902, 0.3536, 0.5708, 0.6141, 0.4785])
# Curr pol
# tensor([0.1903, 0.3538, 0.5706, 0.6134, 0.4785])
# Iter:
# 613
# Inner prox iters used: 17
# Policy 1
# tensor([0.4229, 0.4398, 0.4187, 0.4394, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1903, 0.3538, 0.5706, 0.6134, 0.4785], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4229, 0.4398, 0.4187, 0.4394, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1903, 0.3538, 0.5706, 0.6134, 0.4785], grad_fn=<SqueezeBackward1>)
# tensor(0.3240, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1903, 0.3538, 0.5706, 0.6134, 0.4785])
# Curr pol
# tensor([0.1903, 0.3537, 0.5707, 0.6135, 0.4786])
# Iter:
# 614
# Inner prox iters used: 15
# Policy 1
# tensor([0.4225, 0.4397, 0.4186, 0.4393, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1903, 0.3537, 0.5707, 0.6135, 0.4786], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4225, 0.4397, 0.4186, 0.4393, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1903, 0.3537, 0.5707, 0.6135, 0.4786], grad_fn=<SqueezeBackward1>)
# tensor(0.3241, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1903, 0.3537, 0.5707, 0.6135, 0.4786])
# Curr pol
# tensor([0.1904, 0.3538, 0.5706, 0.6131, 0.4787])
# Iter:
# 615
# Inner prox iters used: 17
# Policy 1
# tensor([0.4222, 0.4395, 0.4184, 0.4393, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1904, 0.3538, 0.5706, 0.6131, 0.4787], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4222, 0.4395, 0.4184, 0.4393, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1904, 0.3538, 0.5706, 0.6131, 0.4787], grad_fn=<SqueezeBackward1>)
# tensor(0.3237, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1904, 0.3538, 0.5706, 0.6131, 0.4787])
# Curr pol
# tensor([0.1905, 0.3538, 0.5705, 0.6129, 0.4788])
# Iter:
# 616
# Inner prox iters used: 11
# Policy 1
# tensor([0.4220, 0.4394, 0.4183, 0.4392, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1905, 0.3538, 0.5705, 0.6129, 0.4788], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4220, 0.4394, 0.4183, 0.4392, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1905, 0.3538, 0.5705, 0.6129, 0.4788], grad_fn=<SqueezeBackward1>)
# tensor(0.3234, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1905, 0.3538, 0.5705, 0.6129, 0.4788])
# Curr pol
# tensor([0.1906, 0.3539, 0.5705, 0.6125, 0.4788])
# Iter:
# 617
# Inner prox iters used: 22
# Policy 1
# tensor([0.4215, 0.4392, 0.4181, 0.4391, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1906, 0.3539, 0.5705, 0.6125, 0.4788], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4215, 0.4392, 0.4181, 0.4391, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1906, 0.3539, 0.5705, 0.6125, 0.4788], grad_fn=<SqueezeBackward1>)
# tensor(0.3230, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1906, 0.3539, 0.5705, 0.6125, 0.4788])
# Curr pol
# tensor([0.1907, 0.3541, 0.5704, 0.6122, 0.4789])
# Iter:
# 618
# Inner prox iters used: 1
# Policy 1
# tensor([0.4215, 0.4392, 0.4181, 0.4391, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1907, 0.3541, 0.5704, 0.6122, 0.4789], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4215, 0.4392, 0.4181, 0.4391, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1907, 0.3541, 0.5704, 0.6122, 0.4789], grad_fn=<SqueezeBackward1>)
# tensor(0.3224, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1907, 0.3541, 0.5704, 0.6122, 0.4789])
# Curr pol
# tensor([0.1908, 0.3541, 0.5703, 0.6119, 0.4790])
# Iter:
# 619
# Inner prox iters used: 14
# Policy 1
# tensor([0.4212, 0.4391, 0.4180, 0.4390, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1908, 0.3541, 0.5703, 0.6119, 0.4790], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4212, 0.4391, 0.4180, 0.4390, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1908, 0.3541, 0.5703, 0.6119, 0.4790], grad_fn=<SqueezeBackward1>)
# tensor(0.3220, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1908, 0.3541, 0.5703, 0.6119, 0.4790])
# Curr pol
# tensor([0.1909, 0.3542, 0.5702, 0.6116, 0.4790])
# Iter:
# 620
# Inner prox iters used: 22
# Policy 1
# tensor([0.4207, 0.4389, 0.4178, 0.4389, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3542, 0.5702, 0.6116, 0.4790], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4207, 0.4389, 0.4178, 0.4389, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3542, 0.5702, 0.6116, 0.4790], grad_fn=<SqueezeBackward1>)
# tensor(0.3215, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1909, 0.3542, 0.5702, 0.6116, 0.4790])
# Curr pol
# tensor([0.1909, 0.3543, 0.5703, 0.6116, 0.4791])
# Iter:
# 621
# Inner prox iters used: 19
# Policy 1
# tensor([0.4204, 0.4387, 0.4176, 0.4389, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3543, 0.5703, 0.6116, 0.4791], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4204, 0.4387, 0.4176, 0.4389, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3543, 0.5703, 0.6116, 0.4791], grad_fn=<SqueezeBackward1>)
# tensor(0.3215, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1909, 0.3543, 0.5703, 0.6116, 0.4791])
# Curr pol
# tensor([0.1911, 0.3543, 0.5702, 0.6114, 0.4792])
# Iter:
# 622
# Inner prox iters used: 2
# Policy 1
# tensor([0.4204, 0.4387, 0.4176, 0.4388, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1911, 0.3543, 0.5702, 0.6114, 0.4792], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4204, 0.4387, 0.4176, 0.4388, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1911, 0.3543, 0.5702, 0.6114, 0.4792], grad_fn=<SqueezeBackward1>)
# tensor(0.3211, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1911, 0.3543, 0.5702, 0.6114, 0.4792])
# Curr pol
# tensor([0.1912, 0.3544, 0.5701, 0.6111, 0.4793])
# Iter:
# 623
# Inner prox iters used: 9
# Policy 1
# tensor([0.4202, 0.4386, 0.4175, 0.4388, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1912, 0.3544, 0.5701, 0.6111, 0.4793], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4202, 0.4386, 0.4175, 0.4388, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1912, 0.3544, 0.5701, 0.6111, 0.4793], grad_fn=<SqueezeBackward1>)
# tensor(0.3207, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1912, 0.3544, 0.5701, 0.6111, 0.4793])
# Curr pol
# tensor([0.1912, 0.3545, 0.5701, 0.6110, 0.4794])
# Iter:
# 624
# Inner prox iters used: 3
# Policy 1
# tensor([0.4201, 0.4386, 0.4175, 0.4388, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1912, 0.3545, 0.5701, 0.6110, 0.4794], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4201, 0.4386, 0.4175, 0.4388, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1912, 0.3545, 0.5701, 0.6110, 0.4794], grad_fn=<SqueezeBackward1>)
# tensor(0.3204, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1912, 0.3545, 0.5701, 0.6110, 0.4794])
# Curr pol
# tensor([0.1912, 0.3545, 0.5701, 0.6105, 0.4794])
# Iter:
# 625
# Inner prox iters used: 11
# Policy 1
# tensor([0.4199, 0.4385, 0.4174, 0.4387, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1912, 0.3545, 0.5701, 0.6105, 0.4794], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4199, 0.4385, 0.4174, 0.4387, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1912, 0.3545, 0.5701, 0.6105, 0.4794], grad_fn=<SqueezeBackward1>)
# tensor(0.3201, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1912, 0.3545, 0.5701, 0.6105, 0.4794])
# Curr pol
# tensor([0.1913, 0.3545, 0.5700, 0.6101, 0.4795])
# Iter:
# 626
# Inner prox iters used: 64
# Policy 1
# tensor([0.4190, 0.4380, 0.4169, 0.4385, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1913, 0.3545, 0.5700, 0.6101, 0.4795], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4190, 0.4380, 0.4169, 0.4385, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1913, 0.3545, 0.5700, 0.6101, 0.4795], grad_fn=<SqueezeBackward1>)
# tensor(0.3198, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1913, 0.3545, 0.5700, 0.6101, 0.4795])
# Curr pol
# tensor([0.1915, 0.3547, 0.5699, 0.6096, 0.4795])
# Iter:
# 627
# Inner prox iters used: 8
# Policy 1
# tensor([0.4189, 0.4379, 0.4168, 0.4385, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1915, 0.3547, 0.5699, 0.6096, 0.4795], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4189, 0.4379, 0.4168, 0.4385, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1915, 0.3547, 0.5699, 0.6096, 0.4795], grad_fn=<SqueezeBackward1>)
# tensor(0.3191, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1915, 0.3547, 0.5699, 0.6096, 0.4795])
# Curr pol
# tensor([0.1916, 0.3548, 0.5698, 0.6094, 0.4795])
# Iter:
# 628
# Inner prox iters used: 18
# Policy 1
# tensor([0.4186, 0.4378, 0.4167, 0.4384, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1916, 0.3548, 0.5698, 0.6094, 0.4795], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4186, 0.4378, 0.4167, 0.4384, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1916, 0.3548, 0.5698, 0.6094, 0.4795], grad_fn=<SqueezeBackward1>)
# tensor(0.3187, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1916, 0.3548, 0.5698, 0.6094, 0.4795])
# Curr pol
# tensor([0.1916, 0.3548, 0.5698, 0.6092, 0.4796])
# Iter:
# 629
# Inner prox iters used: 1
# Policy 1
# tensor([0.4186, 0.4378, 0.4167, 0.4384, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1916, 0.3548, 0.5698, 0.6092, 0.4796], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4186, 0.4378, 0.4167, 0.4384, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1916, 0.3548, 0.5698, 0.6092, 0.4796], grad_fn=<SqueezeBackward1>)
# tensor(0.3184, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1916, 0.3548, 0.5698, 0.6092, 0.4796])
# Curr pol
# tensor([0.1917, 0.3548, 0.5698, 0.6090, 0.4797])
# Iter:
# 630
# Inner prox iters used: 20
# Policy 1
# tensor([0.4183, 0.4376, 0.4165, 0.4383, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1917, 0.3548, 0.5698, 0.6090, 0.4797], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4183, 0.4376, 0.4165, 0.4383, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1917, 0.3548, 0.5698, 0.6090, 0.4797], grad_fn=<SqueezeBackward1>)
# tensor(0.3181, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1917, 0.3548, 0.5698, 0.6090, 0.4797])
# Curr pol
# tensor([0.1907, 0.3540, 0.5711, 0.6121, 0.4802])
# Iter:
# 631
# Inner prox iters used: 15
# Policy 1
# tensor([0.4186, 0.4376, 0.4166, 0.4387, 0.4856], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1907, 0.3540, 0.5711, 0.6121, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4186, 0.4376, 0.4166, 0.4387, 0.4856], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1907, 0.3540, 0.5711, 0.6121, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0.3225, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1907, 0.3540, 0.5711, 0.6121, 0.4802])
# Curr pol
# tensor([0.1909, 0.3541, 0.5710, 0.6116, 0.4802])
# Iter:
# 632
# Inner prox iters used: 1
# Policy 1
# tensor([0.4186, 0.4376, 0.4166, 0.4387, 0.4856], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3541, 0.5710, 0.6116, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4186, 0.4376, 0.4166, 0.4387, 0.4856], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3541, 0.5710, 0.6116, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0.3219, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1909, 0.3541, 0.5710, 0.6116, 0.4802])
# Curr pol
# tensor([0.1909, 0.3541, 0.5710, 0.6114, 0.4803])
# Iter:
# 633
# Inner prox iters used: 20
# Policy 1
# tensor([0.4187, 0.4376, 0.4166, 0.4389, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3541, 0.5710, 0.6114, 0.4803], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4187, 0.4376, 0.4166, 0.4389, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1909, 0.3541, 0.5710, 0.6114, 0.4803], grad_fn=<SqueezeBackward1>)
# tensor(0.3216, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1909, 0.3541, 0.5710, 0.6114, 0.4803])
# Curr pol
# tensor([0.1910, 0.3542, 0.5709, 0.6113, 0.4804])
# Iter:
# 634
# Inner prox iters used: 2
# Policy 1
# tensor([0.4187, 0.4376, 0.4166, 0.4389, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1910, 0.3542, 0.5709, 0.6113, 0.4804], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4187, 0.4376, 0.4166, 0.4389, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1910, 0.3542, 0.5709, 0.6113, 0.4804], grad_fn=<SqueezeBackward1>)
# tensor(0.3213, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1910, 0.3542, 0.5709, 0.6113, 0.4804])
# Curr pol
# tensor([0.1925, 0.3556, 0.5690, 0.6074, 0.4800])
# Iter:
# 635
# Inner prox iters used: 8
# Policy 1
# tensor([0.4184, 0.4375, 0.4164, 0.4387, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1925, 0.3556, 0.5690, 0.6074, 0.4800], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4184, 0.4375, 0.4164, 0.4387, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1925, 0.3556, 0.5690, 0.6074, 0.4800], grad_fn=<SqueezeBackward1>)
# tensor(0.3151, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1925, 0.3556, 0.5690, 0.6074, 0.4800])
# Curr pol
# tensor([0.1925, 0.3557, 0.5691, 0.6072, 0.4800])
# Iter:
# 636
# Inner prox iters used: 30
# Policy 1
# tensor([0.4174, 0.4371, 0.4160, 0.4381, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1925, 0.3557, 0.5691, 0.6072, 0.4800], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4174, 0.4371, 0.4160, 0.4381, 0.4853], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1925, 0.3557, 0.5691, 0.6072, 0.4800], grad_fn=<SqueezeBackward1>)
# tensor(0.3151, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1925, 0.3557, 0.5691, 0.6072, 0.4800])
# Curr pol
# tensor([0.1926, 0.3557, 0.5690, 0.6070, 0.4800])
# Iter:
# 637
# Inner prox iters used: 10
# Policy 1
# tensor([0.4172, 0.4369, 0.4159, 0.4380, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5690, 0.6070, 0.4800], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4172, 0.4369, 0.4159, 0.4380, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5690, 0.6070, 0.4800], grad_fn=<SqueezeBackward1>)
# tensor(0.3148, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1926, 0.3557, 0.5690, 0.6070, 0.4800])
# Curr pol
# tensor([0.1926, 0.3557, 0.5691, 0.6070, 0.4801])
# Iter:
# 638
# Inner prox iters used: 5
# Policy 1
# tensor([0.4171, 0.4369, 0.4158, 0.4379, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6070, 0.4801], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4171, 0.4369, 0.4158, 0.4379, 0.4852], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6070, 0.4801], grad_fn=<SqueezeBackward1>)
# tensor(0.3148, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1926, 0.3557, 0.5691, 0.6070, 0.4801])
# Curr pol
# tensor([0.1926, 0.3557, 0.5691, 0.6067, 0.4802])
# Iter:
# 639
# Inner prox iters used: 15
# Policy 1
# tensor([0.4168, 0.4367, 0.4157, 0.4378, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6067, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4168, 0.4367, 0.4157, 0.4378, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6067, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0.3145, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1926, 0.3557, 0.5691, 0.6067, 0.4802])
# Curr pol
# tensor([0.1926, 0.3557, 0.5691, 0.6066, 0.4802])
# Iter:
# 640
# Inner prox iters used: 13
# Policy 1
# tensor([0.4166, 0.4366, 0.4155, 0.4377, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6066, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4166, 0.4366, 0.4155, 0.4377, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6066, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0.3146, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1926, 0.3557, 0.5691, 0.6066, 0.4802])
# Curr pol
# tensor([0.1926, 0.3557, 0.5691, 0.6065, 0.4802])
# Iter:
# 641
# Inner prox iters used: 8
# Policy 1
# tensor([0.4164, 0.4365, 0.4155, 0.4377, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6065, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4164, 0.4365, 0.4155, 0.4377, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3557, 0.5691, 0.6065, 0.4802], grad_fn=<SqueezeBackward1>)
# tensor(0.3144, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1926, 0.3557, 0.5691, 0.6065, 0.4802])
# Curr pol
# tensor([0.1928, 0.3559, 0.5690, 0.6061, 0.4803])
# Iter:
# 642
# Inner prox iters used: 8
# Policy 1
# tensor([0.4163, 0.4365, 0.4154, 0.4376, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3559, 0.5690, 0.6061, 0.4803], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4163, 0.4365, 0.4154, 0.4376, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3559, 0.5690, 0.6061, 0.4803], grad_fn=<SqueezeBackward1>)
# tensor(0.3137, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1928, 0.3559, 0.5690, 0.6061, 0.4803])
# Curr pol
# tensor([0.1929, 0.3559, 0.5690, 0.6060, 0.4804])
# Iter:
# 643
# Inner prox iters used: 19
# Policy 1
# tensor([0.4160, 0.4363, 0.4152, 0.4375, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1929, 0.3559, 0.5690, 0.6060, 0.4804], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4160, 0.4363, 0.4152, 0.4375, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1929, 0.3559, 0.5690, 0.6060, 0.4804], grad_fn=<SqueezeBackward1>)
# tensor(0.3136, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1929, 0.3559, 0.5690, 0.6060, 0.4804])
# Curr pol
# tensor([0.1930, 0.3560, 0.5689, 0.6056, 0.4804])
# Iter:
# 644
# Inner prox iters used: 2
# Policy 1
# tensor([0.4159, 0.4363, 0.4152, 0.4375, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1930, 0.3560, 0.5689, 0.6056, 0.4804], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4159, 0.4363, 0.4152, 0.4375, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1930, 0.3560, 0.5689, 0.6056, 0.4804], grad_fn=<SqueezeBackward1>)
# tensor(0.3130, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1930, 0.3560, 0.5689, 0.6056, 0.4804])
# Curr pol
# tensor([0.1930, 0.3560, 0.5690, 0.6056, 0.4805])
# Iter:
# 645
# Inner prox iters used: 36
# Policy 1
# tensor([0.4154, 0.4359, 0.4149, 0.4373, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1930, 0.3560, 0.5690, 0.6056, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4154, 0.4359, 0.4149, 0.4373, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1930, 0.3560, 0.5690, 0.6056, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0.3130, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1930, 0.3560, 0.5690, 0.6056, 0.4805])
# Curr pol
# tensor([0.1931, 0.3561, 0.5689, 0.6053, 0.4805])
# Iter:
# 646
# Inner prox iters used: 16
# Policy 1
# tensor([0.4152, 0.4358, 0.4148, 0.4373, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1931, 0.3561, 0.5689, 0.6053, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4152, 0.4358, 0.4148, 0.4373, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1931, 0.3561, 0.5689, 0.6053, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0.3127, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1931, 0.3561, 0.5689, 0.6053, 0.4805])
# Curr pol
# tensor([0.1931, 0.3562, 0.5688, 0.6050, 0.4805])
# Iter:
# 647
# Inner prox iters used: 2
# Policy 1
# tensor([0.4152, 0.4358, 0.4148, 0.4373, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1931, 0.3562, 0.5688, 0.6050, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4152, 0.4358, 0.4148, 0.4373, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1931, 0.3562, 0.5688, 0.6050, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0.3124, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1931, 0.3562, 0.5688, 0.6050, 0.4805])
# Curr pol
# tensor([0.1933, 0.3562, 0.5687, 0.6046, 0.4805])
# Iter:
# 648
# Inner prox iters used: 2
# Policy 1
# tensor([0.4152, 0.4358, 0.4147, 0.4372, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1933, 0.3562, 0.5687, 0.6046, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4152, 0.4358, 0.4147, 0.4372, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1933, 0.3562, 0.5687, 0.6046, 0.4805], grad_fn=<SqueezeBackward1>)
# tensor(0.3119, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1933, 0.3562, 0.5687, 0.6046, 0.4805])
# Curr pol
# tensor([0.1918, 0.3553, 0.5709, 0.6068, 0.4807])
# Iter:
# 649
# Inner prox iters used: 47
# Policy 1
# tensor([0.4160, 0.4358, 0.4148, 0.4380, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1918, 0.3553, 0.5709, 0.6068, 0.4807], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4160, 0.4358, 0.4148, 0.4380, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1918, 0.3553, 0.5709, 0.6068, 0.4807], grad_fn=<SqueezeBackward1>)
# tensor(0.3170, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1918, 0.3553, 0.5709, 0.6068, 0.4807])
# Curr pol
# tensor([0.1919, 0.3554, 0.5709, 0.6067, 0.4808])
# Iter:
# 650
# Inner prox iters used: 18
# Policy 1
# tensor([0.4161, 0.4358, 0.4148, 0.4381, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1919, 0.3554, 0.5709, 0.6067, 0.4808], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4161, 0.4358, 0.4148, 0.4381, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1919, 0.3554, 0.5709, 0.6067, 0.4808], grad_fn=<SqueezeBackward1>)
# tensor(0.3167, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1919, 0.3554, 0.5709, 0.6067, 0.4808])
# Curr pol
# tensor([0.1919, 0.3554, 0.5709, 0.6068, 0.4809])
# Iter:
# 651
# Inner prox iters used: 1
# Policy 1
# tensor([0.4161, 0.4358, 0.4148, 0.4381, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1919, 0.3554, 0.5709, 0.6068, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4161, 0.4358, 0.4148, 0.4381, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1919, 0.3554, 0.5709, 0.6068, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0.3167, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1919, 0.3554, 0.5709, 0.6068, 0.4809])
# Curr pol
# tensor([0.1920, 0.3554, 0.5709, 0.6065, 0.4809])
# Iter:
# 652
# Inner prox iters used: 6
# Policy 1
# tensor([0.4161, 0.4358, 0.4147, 0.4382, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1920, 0.3554, 0.5709, 0.6065, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4161, 0.4358, 0.4147, 0.4382, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1920, 0.3554, 0.5709, 0.6065, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0.3163, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1920, 0.3554, 0.5709, 0.6065, 0.4809])
# Curr pol
# tensor([0.1921, 0.3555, 0.5708, 0.6063, 0.4809])
# Iter:
# 653
# Inner prox iters used: 24
# Policy 1
# tensor([0.4161, 0.4357, 0.4146, 0.4382, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1921, 0.3555, 0.5708, 0.6063, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4161, 0.4357, 0.4146, 0.4382, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1921, 0.3555, 0.5708, 0.6063, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0.3159, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1921, 0.3555, 0.5708, 0.6063, 0.4809])
# Curr pol
# tensor([0.1922, 0.3556, 0.5707, 0.6059, 0.4809])
# Iter:
# 654
# Inner prox iters used: 20
# Policy 1
# tensor([0.4161, 0.4356, 0.4145, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1922, 0.3556, 0.5707, 0.6059, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4161, 0.4356, 0.4145, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1922, 0.3556, 0.5707, 0.6059, 0.4809], grad_fn=<SqueezeBackward1>)
# tensor(0.3155, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1922, 0.3556, 0.5707, 0.6059, 0.4809])
# Curr pol
# tensor([0.1923, 0.3556, 0.5707, 0.6059, 0.4810])
# Iter:
# 655
# Inner prox iters used: 40
# Policy 1
# tensor([0.4160, 0.4355, 0.4143, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1923, 0.3556, 0.5707, 0.6059, 0.4810], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4160, 0.4355, 0.4143, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1923, 0.3556, 0.5707, 0.6059, 0.4810], grad_fn=<SqueezeBackward1>)
# tensor(0.3153, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1923, 0.3556, 0.5707, 0.6059, 0.4810])
# Curr pol
# tensor([0.1924, 0.3557, 0.5707, 0.6058, 0.4811])
# Iter:
# 656
# Inner prox iters used: 8
# Policy 1
# tensor([0.4160, 0.4354, 0.4143, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1924, 0.3557, 0.5707, 0.6058, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4160, 0.4354, 0.4143, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1924, 0.3557, 0.5707, 0.6058, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0.3151, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1924, 0.3557, 0.5707, 0.6058, 0.4811])
# Curr pol
# tensor([0.1924, 0.3557, 0.5707, 0.6057, 0.4811])
# Iter:
# 657
# Inner prox iters used: 13
# Policy 1
# tensor([0.4159, 0.4354, 0.4142, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1924, 0.3557, 0.5707, 0.6057, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4159, 0.4354, 0.4142, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1924, 0.3557, 0.5707, 0.6057, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0.3149, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1924, 0.3557, 0.5707, 0.6057, 0.4811])
# Curr pol
# tensor([0.1926, 0.3559, 0.5705, 0.6052, 0.4811])
# Iter:
# 658
# Inner prox iters used: 1
# Policy 1
# tensor([0.4159, 0.4354, 0.4142, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3559, 0.5705, 0.6052, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4159, 0.4354, 0.4142, 0.4381, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1926, 0.3559, 0.5705, 0.6052, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0.3142, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1926, 0.3559, 0.5705, 0.6052, 0.4811])
# Curr pol
# tensor([0.1927, 0.3560, 0.5704, 0.6050, 0.4811])
# Iter:
# 659
# Inner prox iters used: 8
# Policy 1
# tensor([0.4159, 0.4353, 0.4142, 0.4380, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1927, 0.3560, 0.5704, 0.6050, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4159, 0.4353, 0.4142, 0.4380, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1927, 0.3560, 0.5704, 0.6050, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0.3138, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1927, 0.3560, 0.5704, 0.6050, 0.4811])
# Curr pol
# tensor([0.1927, 0.3560, 0.5704, 0.6049, 0.4811])
# Iter:
# 660
# Inner prox iters used: 9
# Policy 1
# tensor([0.4158, 0.4353, 0.4141, 0.4379, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1927, 0.3560, 0.5704, 0.6049, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4158, 0.4353, 0.4141, 0.4379, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1927, 0.3560, 0.5704, 0.6049, 0.4811], grad_fn=<SqueezeBackward1>)
# tensor(0.3136, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1927, 0.3560, 0.5704, 0.6049, 0.4811])
# Curr pol
# tensor([0.1928, 0.3560, 0.5704, 0.6048, 0.4812])
# Iter:
# 661
# Inner prox iters used: 21
# Policy 1
# tensor([0.4156, 0.4351, 0.4140, 0.4378, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3560, 0.5704, 0.6048, 0.4812], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4156, 0.4351, 0.4140, 0.4378, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3560, 0.5704, 0.6048, 0.4812], grad_fn=<SqueezeBackward1>)
# tensor(0.3134, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1928, 0.3560, 0.5704, 0.6048, 0.4812])
# Curr pol
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813])
# Iter:
# 662
# Inner prox iters used: 1
# Policy 1
# tensor([0.4156, 0.4351, 0.4140, 0.4378, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4156, 0.4351, 0.4140, 0.4378, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0.3135, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813])
# Curr pol
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813])
# Iter:
# 663
# Inner prox iters used: 1
# Policy 1
# tensor([0.4156, 0.4351, 0.4140, 0.4378, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4156, 0.4351, 0.4140, 0.4378, 0.4857], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0.3134, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1928, 0.3562, 0.5704, 0.6052, 0.4813])
# Curr pol
# tensor([0.1934, 0.3568, 0.5702, 0.6042, 0.4815])
# Iter:
# 664
# Inner prox iters used: 42
# Policy 1
# tensor([0.4150, 0.4348, 0.4136, 0.4375, 0.4855], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1934, 0.3568, 0.5702, 0.6042, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4150, 0.4348, 0.4136, 0.4375, 0.4855], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1934, 0.3568, 0.5702, 0.6042, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3115, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1934, 0.3568, 0.5702, 0.6042, 0.4815])
# Curr pol
# tensor([0.1935, 0.3569, 0.5702, 0.6040, 0.4815])
# Iter:
# 665
# Inner prox iters used: 15
# Policy 1
# tensor([0.4149, 0.4347, 0.4135, 0.4374, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1935, 0.3569, 0.5702, 0.6040, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4149, 0.4347, 0.4135, 0.4374, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1935, 0.3569, 0.5702, 0.6040, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3111, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1935, 0.3569, 0.5702, 0.6040, 0.4815])
# Curr pol
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816])
# Iter:
# 666
# Inner prox iters used: 5
# Policy 1
# tensor([0.4149, 0.4347, 0.4135, 0.4374, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4149, 0.4347, 0.4135, 0.4374, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0.3111, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816])
# Curr pol
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816])
# Iter:
# 667
# Inner prox iters used: 7
# Policy 1
# tensor([0.4148, 0.4346, 0.4135, 0.4373, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4148, 0.4346, 0.4135, 0.4373, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0.3110, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1935, 0.3569, 0.5703, 0.6040, 0.4816])
# Curr pol
# tensor([0.1943, 0.3582, 0.5687, 0.6046, 0.4816])
# Iter:
# 668
# Inner prox iters used: 2
# Policy 1
# tensor([0.4148, 0.4346, 0.4135, 0.4373, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1943, 0.3582, 0.5687, 0.6046, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4148, 0.4346, 0.4135, 0.4373, 0.4854], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1943, 0.3582, 0.5687, 0.6046, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0.3086, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1943, 0.3582, 0.5687, 0.6046, 0.4816])
# Curr pol
# tensor([0.1943, 0.3582, 0.5687, 0.6045, 0.4816])
# Iter:
# 669
# Inner prox iters used: 39
# Policy 1
# tensor([0.4141, 0.4342, 0.4132, 0.4369, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1943, 0.3582, 0.5687, 0.6045, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4141, 0.4342, 0.4132, 0.4369, 0.4851], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1943, 0.3582, 0.5687, 0.6045, 0.4816], grad_fn=<SqueezeBackward1>)
# tensor(0.3086, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1943, 0.3582, 0.5687, 0.6045, 0.4816])
# Curr pol
# tensor([0.1945, 0.3584, 0.5684, 0.6038, 0.4815])
# Iter:
# 670
# Inner prox iters used: 23
# Policy 1
# tensor([0.4137, 0.4340, 0.4130, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6038, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4137, 0.4340, 0.4130, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6038, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3077, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1945, 0.3584, 0.5684, 0.6038, 0.4815])
# Curr pol
# tensor([0.1945, 0.3584, 0.5684, 0.6036, 0.4814])
# Iter:
# 671
# Inner prox iters used: 9
# Policy 1
# tensor([0.4136, 0.4339, 0.4129, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6036, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4136, 0.4339, 0.4129, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6036, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3075, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1945, 0.3584, 0.5684, 0.6036, 0.4814])
# Curr pol
# tensor([0.1945, 0.3584, 0.5684, 0.6035, 0.4815])
# Iter:
# 672
# Inner prox iters used: 2
# Policy 1
# tensor([0.4135, 0.4339, 0.4129, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6035, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4135, 0.4339, 0.4129, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6035, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3075, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1945, 0.3584, 0.5684, 0.6035, 0.4815])
# Curr pol
# tensor([0.1945, 0.3584, 0.5684, 0.6033, 0.4814])
# Iter:
# 673
# Inner prox iters used: 1
# Policy 1
# tensor([0.4135, 0.4339, 0.4129, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6033, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4135, 0.4339, 0.4129, 0.4367, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3584, 0.5684, 0.6033, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3074, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1945, 0.3584, 0.5684, 0.6033, 0.4814])
# Curr pol
# tensor([0.1945, 0.3583, 0.5685, 0.6032, 0.4814])
# Iter:
# 674
# Inner prox iters used: 9
# Policy 1
# tensor([0.4134, 0.4338, 0.4129, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3583, 0.5685, 0.6032, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4134, 0.4338, 0.4129, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3583, 0.5685, 0.6032, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3073, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1945, 0.3583, 0.5685, 0.6032, 0.4814])
# Curr pol
# tensor([0.1945, 0.3583, 0.5686, 0.6033, 0.4815])
# Iter:
# 675
# Inner prox iters used: 11
# Policy 1
# tensor([0.4133, 0.4337, 0.4128, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3583, 0.5686, 0.6033, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4133, 0.4337, 0.4128, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1945, 0.3583, 0.5686, 0.6033, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3075, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1945, 0.3583, 0.5686, 0.6033, 0.4815])
# Curr pol
# tensor([0.1946, 0.3583, 0.5686, 0.6030, 0.4815])
# Iter:
# 676
# Inner prox iters used: 3
# Policy 1
# tensor([0.4132, 0.4337, 0.4128, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1946, 0.3583, 0.5686, 0.6030, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4132, 0.4337, 0.4128, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1946, 0.3583, 0.5686, 0.6030, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3073, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1946, 0.3583, 0.5686, 0.6030, 0.4815])
# Curr pol
# tensor([0.1946, 0.3583, 0.5685, 0.6027, 0.4815])
# Iter:
# 677
# Inner prox iters used: 1
# Policy 1
# tensor([0.4132, 0.4337, 0.4128, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1946, 0.3583, 0.5685, 0.6027, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4132, 0.4337, 0.4128, 0.4366, 0.4850], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1946, 0.3583, 0.5685, 0.6027, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3070, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1946, 0.3583, 0.5685, 0.6027, 0.4815])
# Curr pol
# tensor([0.1948, 0.3585, 0.5683, 0.6020, 0.4814])
# Iter:
# 678
# Inner prox iters used: 25
# Policy 1
# tensor([0.4128, 0.4335, 0.4126, 0.4364, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3585, 0.5683, 0.6020, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4128, 0.4335, 0.4126, 0.4364, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3585, 0.5683, 0.6020, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3062, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1948, 0.3585, 0.5683, 0.6020, 0.4814])
# Curr pol
# tensor([0.1948, 0.3586, 0.5682, 0.6018, 0.4814])
# Iter:
# 679
# Inner prox iters used: 9
# Policy 1
# tensor([0.4126, 0.4334, 0.4125, 0.4363, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3586, 0.5682, 0.6018, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4126, 0.4334, 0.4125, 0.4363, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3586, 0.5682, 0.6018, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3060, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1948, 0.3586, 0.5682, 0.6018, 0.4814])
# Curr pol
# tensor([0.1949, 0.3586, 0.5682, 0.6015, 0.4814])
# Iter:
# 680
# Inner prox iters used: 11
# Policy 1
# tensor([0.4125, 0.4333, 0.4124, 0.4362, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1949, 0.3586, 0.5682, 0.6015, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4125, 0.4333, 0.4124, 0.4362, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1949, 0.3586, 0.5682, 0.6015, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3056, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1949, 0.3586, 0.5682, 0.6015, 0.4814])
# Curr pol
# tensor([0.1948, 0.3586, 0.5682, 0.6014, 0.4814])
# Iter:
# 681
# Inner prox iters used: 17
# Policy 1
# tensor([0.4123, 0.4332, 0.4123, 0.4362, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3586, 0.5682, 0.6014, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4123, 0.4332, 0.4123, 0.4362, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3586, 0.5682, 0.6014, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3058, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1948, 0.3586, 0.5682, 0.6014, 0.4814])
# Curr pol
# tensor([0.1948, 0.3585, 0.5683, 0.6014, 0.4814])
# Iter:
# 682
# Inner prox iters used: 21
# Policy 1
# tensor([0.4121, 0.4330, 0.4122, 0.4361, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3585, 0.5683, 0.6014, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4121, 0.4330, 0.4122, 0.4361, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3585, 0.5683, 0.6014, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3059, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1948, 0.3585, 0.5683, 0.6014, 0.4814])
# Curr pol
# tensor([0.1948, 0.3585, 0.5684, 0.6014, 0.4814])
# Iter:
# 683
# Inner prox iters used: 10
# Policy 1
# tensor([0.4120, 0.4330, 0.4121, 0.4361, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3585, 0.5684, 0.6014, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4330, 0.4121, 0.4361, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1948, 0.3585, 0.5684, 0.6014, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3059, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1948, 0.3585, 0.5684, 0.6014, 0.4814])
# Curr pol
# tensor([0.1951, 0.3588, 0.5680, 0.6005, 0.4813])
# Iter:
# 684
# Inner prox iters used: 5
# Policy 1
# tensor([0.4119, 0.4329, 0.4121, 0.4361, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1951, 0.3588, 0.5680, 0.6005, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4329, 0.4121, 0.4361, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1951, 0.3588, 0.5680, 0.6005, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0.3048, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1951, 0.3588, 0.5680, 0.6005, 0.4813])
# Curr pol
# tensor([0.1950, 0.3588, 0.5680, 0.6005, 0.4814])
# Iter:
# 685
# Inner prox iters used: 8
# Policy 1
# tensor([0.4118, 0.4328, 0.4120, 0.4360, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1950, 0.3588, 0.5680, 0.6005, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4118, 0.4328, 0.4120, 0.4360, 0.4848], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1950, 0.3588, 0.5680, 0.6005, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3048, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1950, 0.3588, 0.5680, 0.6005, 0.4814])
# Curr pol
# tensor([0.1950, 0.3589, 0.5680, 0.6001, 0.4813])
# Iter:
# 686
# Inner prox iters used: 13
# Policy 1
# tensor([0.4116, 0.4327, 0.4119, 0.4360, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1950, 0.3589, 0.5680, 0.6001, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4116, 0.4327, 0.4119, 0.4360, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1950, 0.3589, 0.5680, 0.6001, 0.4813], grad_fn=<SqueezeBackward1>)
# tensor(0.3047, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1950, 0.3589, 0.5680, 0.6001, 0.4813])
# Curr pol
# tensor([0.1950, 0.3589, 0.5680, 0.6000, 0.4814])
# Iter:
# 687
# Inner prox iters used: 3
# Policy 1
# tensor([0.4116, 0.4327, 0.4119, 0.4359, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1950, 0.3589, 0.5680, 0.6000, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4116, 0.4327, 0.4119, 0.4359, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1950, 0.3589, 0.5680, 0.6000, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3047, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1950, 0.3589, 0.5680, 0.6000, 0.4814])
# Curr pol
# tensor([0.1949, 0.3589, 0.5681, 0.6001, 0.4814])
# Iter:
# 688
# Inner prox iters used: 3
# Policy 1
# tensor([0.4116, 0.4327, 0.4119, 0.4359, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1949, 0.3589, 0.5681, 0.6001, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4116, 0.4327, 0.4119, 0.4359, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1949, 0.3589, 0.5681, 0.6001, 0.4814], grad_fn=<SqueezeBackward1>)
# tensor(0.3048, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1949, 0.3589, 0.5681, 0.6001, 0.4814])
# Curr pol
# tensor([0.1949, 0.3588, 0.5682, 0.6002, 0.4815])
# Iter:
# 689
# Inner prox iters used: 8
# Policy 1
# tensor([0.4115, 0.4326, 0.4118, 0.4359, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1949, 0.3588, 0.5682, 0.6002, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4115, 0.4326, 0.4118, 0.4359, 0.4847], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1949, 0.3588, 0.5682, 0.6002, 0.4815], grad_fn=<SqueezeBackward1>)
# tensor(0.3050, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1949, 0.3588, 0.5682, 0.6002, 0.4815])
# Curr pol
# tensor([0.1952, 0.3543, 0.5767, 0.6225, 0.4862])
# Iter:
# 690
# Inner prox iters used: 71
# Policy 1
# tensor([0.4180, 0.4343, 0.4145, 0.4410, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1952, 0.3543, 0.5767, 0.6225, 0.4862], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4180, 0.4343, 0.4145, 0.4410, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# ...
# Policy 2
# tensor([0.1975, 0.3552, 0.5698, 0.5994, 0.4844], grad_fn=<SqueezeBackward1>)
# tensor(0.3021, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1975, 0.3552, 0.5698, 0.5994, 0.4844])
# Curr pol
# tensor([0.1974, 0.3550, 0.5699, 0.5997, 0.4844])
# Iter:
# 873
# Inner prox iters used: 10
# Policy 1
# tensor([0.4081, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3550, 0.5699, 0.5997, 0.4844], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4081, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3550, 0.5699, 0.5997, 0.4844], grad_fn=<SqueezeBackward1>)
# tensor(0.3026, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1974, 0.3550, 0.5699, 0.5997, 0.4844])
# Curr pol
# tensor([0.1974, 0.3551, 0.5697, 0.5994, 0.4842])
# Iter:
# 874
# Inner prox iters used: 44
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3551, 0.5697, 0.5994, 0.4842], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3551, 0.5697, 0.5994, 0.4842], grad_fn=<SqueezeBackward1>)
# tensor(0.3023, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1974, 0.3551, 0.5697, 0.5994, 0.4842])
# Curr pol
# tensor([0.1974, 0.3552, 0.5697, 0.5993, 0.4842])
# Iter:
# 875
# Inner prox iters used: 5
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3552, 0.5697, 0.5993, 0.4842], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3552, 0.5697, 0.5993, 0.4842], grad_fn=<SqueezeBackward1>)
# tensor(0.3024, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1974, 0.3552, 0.5697, 0.5993, 0.4842])
# Curr pol
# tensor([0.1975, 0.3553, 0.5695, 0.5989, 0.4840])
# Iter:
# 876
# Inner prox iters used: 1
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1975, 0.3553, 0.5695, 0.5989, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1975, 0.3553, 0.5695, 0.5989, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0.3018, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1975, 0.3553, 0.5695, 0.5989, 0.4840])
# Curr pol
# tensor([0.1974, 0.3553, 0.5695, 0.5988, 0.4840])
# Iter:
# 877
# Inner prox iters used: 1
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3553, 0.5695, 0.5988, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3553, 0.5695, 0.5988, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0.3019, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1974, 0.3553, 0.5695, 0.5988, 0.4840])
# Curr pol
# tensor([0.1974, 0.3553, 0.5696, 0.5988, 0.4839])
# Iter:
# 878
# Inner prox iters used: 3
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3553, 0.5696, 0.5988, 0.4839], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4084, 0.4293, 0.4094, 0.4369, 0.4858], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1974, 0.3553, 0.5696, 0.5988, 0.4839], grad_fn=<SqueezeBackward1>)
# tensor(0.3020, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1974, 0.3553, 0.5696, 0.5988, 0.4839])
# Curr pol
# tensor([0.1971, 0.3552, 0.5699, 0.5998, 0.4840])
# Iter:
# 879
# Inner prox iters used: 24
# Policy 1
# tensor([0.4087, 0.4294, 0.4094, 0.4370, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1971, 0.3552, 0.5699, 0.5998, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4087, 0.4294, 0.4094, 0.4370, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1971, 0.3552, 0.5699, 0.5998, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0.3032, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1971, 0.3552, 0.5699, 0.5998, 0.4840])
# Curr pol
# tensor([0.1970, 0.3552, 0.5699, 0.5997, 0.4839])
# Iter:
# 880
# Inner prox iters used: 1
# Policy 1
# tensor([0.4087, 0.4294, 0.4094, 0.4370, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1970, 0.3552, 0.5699, 0.5997, 0.4839], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4087, 0.4294, 0.4094, 0.4370, 0.4859], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1970, 0.3552, 0.5699, 0.5997, 0.4839], grad_fn=<SqueezeBackward1>)
# tensor(0.3033, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1970, 0.3552, 0.5699, 0.5997, 0.4839])
# Curr pol
# tensor([0.1964, 0.3546, 0.5708, 0.6017, 0.4842])
# Iter:
# 881
# Inner prox iters used: 8
# Policy 1
# tensor([0.4089, 0.4295, 0.4095, 0.4371, 0.4860], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1964, 0.3546, 0.5708, 0.6017, 0.4842], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4089, 0.4295, 0.4095, 0.4371, 0.4860], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1964, 0.3546, 0.5708, 0.6017, 0.4842], grad_fn=<SqueezeBackward1>)
# tensor(0.3059, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1964, 0.3546, 0.5708, 0.6017, 0.4842])
# Curr pol
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4841])
# Iter:
# 882
# Inner prox iters used: 10
# Policy 1
# tensor([0.4091, 0.4295, 0.4096, 0.4373, 0.4861], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4841], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4091, 0.4295, 0.4096, 0.4373, 0.4861], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4841], grad_fn=<SqueezeBackward1>)
# tensor(0.3055, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4841])
# Curr pol
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4840])
# Iter:
# 883
# Inner prox iters used: 7
# Policy 1
# tensor([0.4093, 0.4296, 0.4096, 0.4373, 0.4862], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4093, 0.4296, 0.4096, 0.4373, 0.4862], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0.3056, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1965, 0.3547, 0.5707, 0.6014, 0.4840])
# Curr pol
# tensor([0.1963, 0.3545, 0.5710, 0.6021, 0.4841])
# Iter:
# 884
# Inner prox iters used: 11
# Policy 1
# tensor([0.4095, 0.4297, 0.4097, 0.4375, 0.4863], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1963, 0.3545, 0.5710, 0.6021, 0.4841], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4095, 0.4297, 0.4097, 0.4375, 0.4863], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1963, 0.3545, 0.5710, 0.6021, 0.4841], grad_fn=<SqueezeBackward1>)
# tensor(0.3065, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1963, 0.3545, 0.5710, 0.6021, 0.4841])
# Curr pol
# tensor([0.1962, 0.3545, 0.5710, 0.6022, 0.4840])
# Iter:
# 885
# Inner prox iters used: 16
# Policy 1
# tensor([0.4099, 0.4298, 0.4098, 0.4377, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1962, 0.3545, 0.5710, 0.6022, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4099, 0.4298, 0.4098, 0.4377, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1962, 0.3545, 0.5710, 0.6022, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0.3066, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1962, 0.3545, 0.5710, 0.6022, 0.4840])
# Curr pol
# tensor([0.1962, 0.3546, 0.5709, 0.6020, 0.4840])
# Iter:
# 886
# Inner prox iters used: 18
# Policy 1
# tensor([0.4102, 0.4299, 0.4098, 0.4378, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1962, 0.3546, 0.5709, 0.6020, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4102, 0.4299, 0.4098, 0.4378, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1962, 0.3546, 0.5709, 0.6020, 0.4840], grad_fn=<SqueezeBackward1>)
# tensor(0.3064, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1962, 0.3546, 0.5709, 0.6020, 0.4840])
# Curr pol
# tensor([0.1962, 0.3546, 0.5709, 0.6021, 0.4839])
# Iter:
# 887
# Inner prox iters used: 13
# Policy 1
# tensor([0.4103, 0.4299, 0.4099, 0.4378, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1962, 0.3546, 0.5709, 0.6021, 0.4839], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4103, 0.4299, 0.4099, 0.4378, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1962, 0.3546, 0.5709, 0.6021, 0.4839], grad_fn=<SqueezeBackward1>)
# tensor(0.3066, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1962, 0.3546, 0.5709, 0.6021, 0.4839])
# Curr pol
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838])
# Iter:
# 888
# Inner prox iters used: 13
# Policy 1
# tensor([0.4105, 0.4300, 0.4099, 0.4379, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4105, 0.4300, 0.4099, 0.4379, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838], grad_fn=<SqueezeBackward1>)
# tensor(0.3067, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838])
# Curr pol
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838])
# Iter:
# 889
# Inner prox iters used: 5
# Policy 1
# tensor([0.4105, 0.4300, 0.4099, 0.4379, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4105, 0.4300, 0.4099, 0.4379, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838], grad_fn=<SqueezeBackward1>)
# tensor(0.3067, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3546, 0.5709, 0.6020, 0.4838])
# Curr pol
# tensor([0.1961, 0.3546, 0.5709, 0.6019, 0.4837])
# Iter:
# 890
# Inner prox iters used: 2
# Policy 1
# tensor([0.4106, 0.4300, 0.4099, 0.4379, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3546, 0.5709, 0.6019, 0.4837], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4106, 0.4300, 0.4099, 0.4379, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3546, 0.5709, 0.6019, 0.4837], grad_fn=<SqueezeBackward1>)
# tensor(0.3066, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3546, 0.5709, 0.6019, 0.4837])
# Curr pol
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4837])
# Iter:
# 891
# Inner prox iters used: 3
# Policy 1
# tensor([0.4106, 0.4300, 0.4099, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4837], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4106, 0.4300, 0.4099, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4837], grad_fn=<SqueezeBackward1>)
# tensor(0.3066, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4837])
# Curr pol
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836])
# Iter:
# 892
# Inner prox iters used: 7
# Policy 1
# tensor([0.4106, 0.4300, 0.4099, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4106, 0.4300, 0.4099, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836], grad_fn=<SqueezeBackward1>)
# tensor(0.3066, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836])
# Curr pol
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836])
# Iter:
# 893
# Inner prox iters used: 17
# Policy 1
# tensor([0.4108, 0.4301, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4108, 0.4301, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836], grad_fn=<SqueezeBackward1>)
# tensor(0.3066, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3547, 0.5708, 0.6018, 0.4836])
# Curr pol
# tensor([0.1960, 0.3547, 0.5708, 0.6019, 0.4835])
# Iter:
# 894
# Inner prox iters used: 8
# Policy 1
# tensor([0.4108, 0.4301, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1960, 0.3547, 0.5708, 0.6019, 0.4835], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4108, 0.4301, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1960, 0.3547, 0.5708, 0.6019, 0.4835], grad_fn=<SqueezeBackward1>)
# tensor(0.3068, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1960, 0.3547, 0.5708, 0.6019, 0.4835])
# Curr pol
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835])
# Iter:
# 895
# Inner prox iters used: 10
# Policy 1
# tensor([0.4109, 0.4301, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4109, 0.4301, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835], grad_fn=<SqueezeBackward1>)
# tensor(0.3069, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835])
# Curr pol
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835])
# Iter:
# 896
# Inner prox iters used: 6
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4379, 0.4864], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835], grad_fn=<SqueezeBackward1>)
# tensor(0.3069, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1959, 0.3547, 0.5709, 0.6019, 0.4835])
# Curr pol
# tensor([0.1960, 0.3548, 0.5707, 0.6016, 0.4834])
# Iter:
# 897
# Inner prox iters used: 10
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4379, 0.4863], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1960, 0.3548, 0.5707, 0.6016, 0.4834], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4379, 0.4863], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1960, 0.3548, 0.5707, 0.6016, 0.4834], grad_fn=<SqueezeBackward1>)
# tensor(0.3066, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1960, 0.3548, 0.5707, 0.6016, 0.4834])
# Curr pol
# tensor([0.1961, 0.3550, 0.5705, 0.6011, 0.4833])
# Iter:
# 898
# Inner prox iters used: 7
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4378, 0.4863], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3550, 0.5705, 0.6011, 0.4833], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4378, 0.4863], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3550, 0.5705, 0.6011, 0.4833], grad_fn=<SqueezeBackward1>)
# tensor(0.3060, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3550, 0.5705, 0.6011, 0.4833])
# Curr pol
# tensor([0.1961, 0.3550, 0.5705, 0.6010, 0.4833])
# Iter:
# 899
# Inner prox iters used: 8
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4378, 0.4862], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3550, 0.5705, 0.6010, 0.4833], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4110, 0.4302, 0.4100, 0.4378, 0.4862], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3550, 0.5705, 0.6010, 0.4833], grad_fn=<SqueezeBackward1>)
# tensor(0.3059, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3550, 0.5705, 0.6010, 0.4833])
# Curr pol
# tensor([0.1961, 0.3551, 0.5705, 0.6010, 0.4832])
# Iter:
# 900
# Outer prox iters used: 900
# Epoch: 1
# Time Elapsed: 2761.8 seconds
# Discounted Rewards: tensor([3.1618, 3.1678])
# Max Avg Coop Payout (Infinite Horizon): 8.250
# Policy 1
# tensor([0.1956, 0.5728, 0.3577, 0.5978, 0.4820], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.1961, 0.3551, 0.5705, 0.6010, 0.4832], grad_fn=<SqueezeBackward1>)

# %%
# POLA update with custom param 4 (size 2 neural net)
# !python LOLA_exact.py --n_agents 2 --using_nn --nn_hidden_size 2 --custom_param 4 --print_every 1 --repeats 1 --num_epochs 1 --init_state_representation 2  --set_seed --seed 1 --lr_policies_inner 0.003 --lr_policies_outer .003 --actual_update --base_cf_no_scale 1.33 --inner_exact_prox --inner_beta 2 --outer_exact_prox --outer_beta 5 --print_prox_loops_info
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor([0.3822, 0.4237, 0.4171, 0.4375, 0.4887], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2295, 0.3225, 0.5703, 0.6259, 0.4986], grad_fn=<SqueezeBackward1>)
# tensor(0.2832, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2295, 0.3225, 0.5703, 0.6259, 0.4986])
# Curr pol
# tensor([0.2293, 0.3226, 0.5702, 0.6259, 0.4985])
# Iter:
# 366
# Inner prox iters used: 22
# Policy 1
# tensor([0.3827, 0.4241, 0.4173, 0.4377, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2293, 0.3226, 0.5702, 0.6259, 0.4985], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3827, 0.4241, 0.4173, 0.4377, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2293, 0.3226, 0.5702, 0.6259, 0.4985], grad_fn=<SqueezeBackward1>)
# tensor(0.2834, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2293, 0.3226, 0.5702, 0.6259, 0.4985])
# Curr pol
# tensor([0.2292, 0.3228, 0.5701, 0.6260, 0.4984])
# Iter:
# 367
# Inner prox iters used: 16
# Policy 1
# tensor([0.3830, 0.4243, 0.4174, 0.4378, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2292, 0.3228, 0.5701, 0.6260, 0.4984], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3830, 0.4243, 0.4174, 0.4378, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2292, 0.3228, 0.5701, 0.6260, 0.4984], grad_fn=<SqueezeBackward1>)
# tensor(0.2834, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2292, 0.3228, 0.5701, 0.6260, 0.4984])
# Curr pol
# tensor([0.2291, 0.3229, 0.5701, 0.6260, 0.4982])
# Iter:
# 368
# Inner prox iters used: 16
# Policy 1
# tensor([0.3833, 0.4245, 0.4175, 0.4379, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2291, 0.3229, 0.5701, 0.6260, 0.4982], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3833, 0.4245, 0.4175, 0.4379, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2291, 0.3229, 0.5701, 0.6260, 0.4982], grad_fn=<SqueezeBackward1>)
# tensor(0.2835, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2291, 0.3229, 0.5701, 0.6260, 0.4982])
# Curr pol
# tensor([0.2290, 0.3230, 0.5700, 0.6261, 0.4981])
# Iter:
# 369
# Inner prox iters used: 1
# Policy 1
# tensor([0.3833, 0.4245, 0.4176, 0.4379, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2290, 0.3230, 0.5700, 0.6261, 0.4981], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3833, 0.4245, 0.4176, 0.4379, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2290, 0.3230, 0.5700, 0.6261, 0.4981], grad_fn=<SqueezeBackward1>)
# tensor(0.2836, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2290, 0.3230, 0.5700, 0.6261, 0.4981])
# Curr pol
# tensor([0.2288, 0.3231, 0.5701, 0.6262, 0.4980])
# Iter:
# 370
# Inner prox iters used: 4
# Policy 1
# tensor([0.3834, 0.4245, 0.4176, 0.4379, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2288, 0.3231, 0.5701, 0.6262, 0.4980], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3834, 0.4245, 0.4176, 0.4379, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2288, 0.3231, 0.5701, 0.6262, 0.4980], grad_fn=<SqueezeBackward1>)
# tensor(0.2839, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2288, 0.3231, 0.5701, 0.6262, 0.4980])
# Curr pol
# tensor([0.2287, 0.3232, 0.5700, 0.6262, 0.4979])
# Iter:
# 371
# Inner prox iters used: 15
# Policy 1
# tensor([0.3836, 0.4247, 0.4177, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2287, 0.3232, 0.5700, 0.6262, 0.4979], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3836, 0.4247, 0.4177, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2287, 0.3232, 0.5700, 0.6262, 0.4979], grad_fn=<SqueezeBackward1>)
# tensor(0.2840, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2287, 0.3232, 0.5700, 0.6262, 0.4979])
# Curr pol
# tensor([0.2286, 0.3234, 0.5700, 0.6263, 0.4978])
# Iter:
# 372
# Inner prox iters used: 6
# Policy 1
# tensor([0.3837, 0.4248, 0.4177, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2286, 0.3234, 0.5700, 0.6263, 0.4978], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3837, 0.4248, 0.4177, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2286, 0.3234, 0.5700, 0.6263, 0.4978], grad_fn=<SqueezeBackward1>)
# tensor(0.2840, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2286, 0.3234, 0.5700, 0.6263, 0.4978])
# Curr pol
# tensor([0.2285, 0.3235, 0.5700, 0.6263, 0.4977])
# Iter:
# 373
# Inner prox iters used: 7
# Policy 1
# tensor([0.3838, 0.4248, 0.4177, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2285, 0.3235, 0.5700, 0.6263, 0.4977], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3838, 0.4248, 0.4177, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2285, 0.3235, 0.5700, 0.6263, 0.4977], grad_fn=<SqueezeBackward1>)
# tensor(0.2842, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2285, 0.3235, 0.5700, 0.6263, 0.4977])
# Curr pol
# tensor([0.2283, 0.3237, 0.5699, 0.6264, 0.4976])
# Iter:
# 374
# Inner prox iters used: 4
# Policy 1
# tensor([0.3839, 0.4249, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2283, 0.3237, 0.5699, 0.6264, 0.4976], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3839, 0.4249, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2283, 0.3237, 0.5699, 0.6264, 0.4976], grad_fn=<SqueezeBackward1>)
# tensor(0.2842, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2283, 0.3237, 0.5699, 0.6264, 0.4976])
# Curr pol
# tensor([0.2282, 0.3238, 0.5699, 0.6264, 0.4974])
# Iter:
# 375
# Inner prox iters used: 1
# Policy 1
# tensor([0.3839, 0.4249, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2282, 0.3238, 0.5699, 0.6264, 0.4974], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3839, 0.4249, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2282, 0.3238, 0.5699, 0.6264, 0.4974], grad_fn=<SqueezeBackward1>)
# tensor(0.2843, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2282, 0.3238, 0.5699, 0.6264, 0.4974])
# Curr pol
# tensor([0.2281, 0.3239, 0.5698, 0.6265, 0.4973])
# Iter:
# 376
# Inner prox iters used: 1
# Policy 1
# tensor([0.3839, 0.4249, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2281, 0.3239, 0.5698, 0.6265, 0.4973], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3839, 0.4249, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2281, 0.3239, 0.5698, 0.6265, 0.4973], grad_fn=<SqueezeBackward1>)
# tensor(0.2844, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2281, 0.3239, 0.5698, 0.6265, 0.4973])
# Curr pol
# tensor([0.2280, 0.3240, 0.5698, 0.6265, 0.4972])
# Iter:
# 377
# Inner prox iters used: 7
# Policy 1
# tensor([0.3841, 0.4250, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2280, 0.3240, 0.5698, 0.6265, 0.4972], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3841, 0.4250, 0.4178, 0.4380, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2280, 0.3240, 0.5698, 0.6265, 0.4972], grad_fn=<SqueezeBackward1>)
# tensor(0.2846, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2280, 0.3240, 0.5698, 0.6265, 0.4972])
# Curr pol
# tensor([0.2278, 0.3241, 0.5697, 0.6266, 0.4971])
# Iter:
# 378
# Inner prox iters used: 70
# Policy 1
# tensor([0.3850, 0.4255, 0.4180, 0.4381, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2278, 0.3241, 0.5697, 0.6266, 0.4971], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3850, 0.4255, 0.4180, 0.4381, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2278, 0.3241, 0.5697, 0.6266, 0.4971], grad_fn=<SqueezeBackward1>)
# tensor(0.2846, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2278, 0.3241, 0.5697, 0.6266, 0.4971])
# Curr pol
# tensor([0.2277, 0.3243, 0.5697, 0.6266, 0.4970])
# Iter:
# 379
# Inner prox iters used: 1
# Policy 1
# tensor([0.3850, 0.4256, 0.4180, 0.4381, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2277, 0.3243, 0.5697, 0.6266, 0.4970], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3850, 0.4256, 0.4180, 0.4381, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2277, 0.3243, 0.5697, 0.6266, 0.4970], grad_fn=<SqueezeBackward1>)
# tensor(0.2847, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2277, 0.3243, 0.5697, 0.6266, 0.4970])
# Curr pol
# tensor([0.2276, 0.3244, 0.5697, 0.6266, 0.4969])
# Iter:
# 380
# Inner prox iters used: 6
# Policy 1
# tensor([0.3851, 0.4256, 0.4180, 0.4381, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2276, 0.3244, 0.5697, 0.6266, 0.4969], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3851, 0.4256, 0.4180, 0.4381, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2276, 0.3244, 0.5697, 0.6266, 0.4969], grad_fn=<SqueezeBackward1>)
# tensor(0.2848, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2276, 0.3244, 0.5697, 0.6266, 0.4969])
# Curr pol
# tensor([0.2275, 0.3246, 0.5696, 0.6267, 0.4968])
# Iter:
# 381
# Inner prox iters used: 29
# Policy 1
# tensor([0.3854, 0.4258, 0.4181, 0.4380, 0.4887], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2275, 0.3246, 0.5696, 0.6267, 0.4968], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3854, 0.4258, 0.4181, 0.4380, 0.4887], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2275, 0.3246, 0.5696, 0.6267, 0.4968], grad_fn=<SqueezeBackward1>)
# tensor(0.2849, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2275, 0.3246, 0.5696, 0.6267, 0.4968])
# Curr pol
# tensor([0.2274, 0.3247, 0.5696, 0.6268, 0.4967])
# Iter:
# 382
# Inner prox iters used: 21
# Policy 1
# tensor([0.3856, 0.4259, 0.4181, 0.4380, 0.4887], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2274, 0.3247, 0.5696, 0.6268, 0.4967], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3856, 0.4259, 0.4181, 0.4380, 0.4887], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2274, 0.3247, 0.5696, 0.6268, 0.4967], grad_fn=<SqueezeBackward1>)
# tensor(0.2850, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2274, 0.3247, 0.5696, 0.6268, 0.4967])
# Curr pol
# tensor([0.2272, 0.3248, 0.5696, 0.6269, 0.4967])
# Iter:
# 383
# Inner prox iters used: 15
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2272, 0.3248, 0.5696, 0.6269, 0.4967], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2272, 0.3248, 0.5696, 0.6269, 0.4967], grad_fn=<SqueezeBackward1>)
# tensor(0.2852, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2272, 0.3248, 0.5696, 0.6269, 0.4967])
# Curr pol
# tensor([0.2272, 0.3250, 0.5695, 0.6268, 0.4965])
# Iter:
# 384
# Inner prox iters used: 3
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2272, 0.3250, 0.5695, 0.6268, 0.4965], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2272, 0.3250, 0.5695, 0.6268, 0.4965], grad_fn=<SqueezeBackward1>)
# tensor(0.2852, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2272, 0.3250, 0.5695, 0.6268, 0.4965])
# Curr pol
# tensor([0.2270, 0.3251, 0.5695, 0.6269, 0.4964])
# Iter:
# 385
# Inner prox iters used: 2
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2270, 0.3251, 0.5695, 0.6269, 0.4964], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2270, 0.3251, 0.5695, 0.6269, 0.4964], grad_fn=<SqueezeBackward1>)
# tensor(0.2852, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2270, 0.3251, 0.5695, 0.6269, 0.4964])
# Curr pol
# tensor([0.2269, 0.3252, 0.5694, 0.6269, 0.4963])
# Iter:
# 386
# Inner prox iters used: 1
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2269, 0.3252, 0.5694, 0.6269, 0.4963], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2269, 0.3252, 0.5694, 0.6269, 0.4963], grad_fn=<SqueezeBackward1>)
# tensor(0.2853, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2269, 0.3252, 0.5694, 0.6269, 0.4963])
# Curr pol
# tensor([0.2268, 0.3254, 0.5694, 0.6269, 0.4962])
# Iter:
# 387
# Inner prox iters used: 2
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2268, 0.3254, 0.5694, 0.6269, 0.4962], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3858, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2268, 0.3254, 0.5694, 0.6269, 0.4962], grad_fn=<SqueezeBackward1>)
# tensor(0.2853, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2268, 0.3254, 0.5694, 0.6269, 0.4962])
# Curr pol
# tensor([0.2268, 0.3256, 0.5692, 0.6268, 0.4960])
# Iter:
# 388
# Inner prox iters used: 5
# Policy 1
# tensor([0.3859, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2268, 0.3256, 0.5692, 0.6268, 0.4960], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3859, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2268, 0.3256, 0.5692, 0.6268, 0.4960], grad_fn=<SqueezeBackward1>)
# tensor(0.2852, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2268, 0.3256, 0.5692, 0.6268, 0.4960])
# Curr pol
# tensor([0.2266, 0.3257, 0.5692, 0.6269, 0.4959])
# Iter:
# 389
# Inner prox iters used: 1
# Policy 1
# tensor([0.3859, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2266, 0.3257, 0.5692, 0.6269, 0.4959], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3859, 0.4260, 0.4181, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2266, 0.3257, 0.5692, 0.6269, 0.4959], grad_fn=<SqueezeBackward1>)
# tensor(0.2854, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2266, 0.3257, 0.5692, 0.6269, 0.4959])
# Curr pol
# tensor([0.2265, 0.3257, 0.5692, 0.6271, 0.4959])
# Iter:
# 390
# Inner prox iters used: 7
# Policy 1
# tensor([0.3860, 0.4261, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2265, 0.3257, 0.5692, 0.6271, 0.4959], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3860, 0.4261, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2265, 0.3257, 0.5692, 0.6271, 0.4959], grad_fn=<SqueezeBackward1>)
# tensor(0.2857, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2265, 0.3257, 0.5692, 0.6271, 0.4959])
# Curr pol
# tensor([0.2264, 0.3259, 0.5692, 0.6271, 0.4958])
# Iter:
# 391
# Inner prox iters used: 12
# Policy 1
# tensor([0.3861, 0.4262, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2264, 0.3259, 0.5692, 0.6271, 0.4958], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3861, 0.4262, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2264, 0.3259, 0.5692, 0.6271, 0.4958], grad_fn=<SqueezeBackward1>)
# tensor(0.2858, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2264, 0.3259, 0.5692, 0.6271, 0.4958])
# Curr pol
# tensor([0.2262, 0.3260, 0.5692, 0.6272, 0.4957])
# Iter:
# 392
# Inner prox iters used: 3
# Policy 1
# tensor([0.3862, 0.4262, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2262, 0.3260, 0.5692, 0.6272, 0.4957], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3862, 0.4262, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2262, 0.3260, 0.5692, 0.6272, 0.4957], grad_fn=<SqueezeBackward1>)
# tensor(0.2860, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2262, 0.3260, 0.5692, 0.6272, 0.4957])
# Curr pol
# tensor([0.2261, 0.3261, 0.5691, 0.6272, 0.4956])
# Iter:
# 393
# Inner prox iters used: 12
# Policy 1
# tensor([0.3863, 0.4263, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2261, 0.3261, 0.5691, 0.6272, 0.4956], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3863, 0.4263, 0.4182, 0.4380, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2261, 0.3261, 0.5691, 0.6272, 0.4956], grad_fn=<SqueezeBackward1>)
# tensor(0.2859, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2261, 0.3261, 0.5691, 0.6272, 0.4956])
# Curr pol
# tensor([0.2260, 0.3263, 0.5691, 0.6272, 0.4955])
# Iter:
# 394
# Inner prox iters used: 24
# Policy 1
# tensor([0.3866, 0.4264, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2260, 0.3263, 0.5691, 0.6272, 0.4955], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3866, 0.4264, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2260, 0.3263, 0.5691, 0.6272, 0.4955], grad_fn=<SqueezeBackward1>)
# tensor(0.2860, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2260, 0.3263, 0.5691, 0.6272, 0.4955])
# Curr pol
# tensor([0.2259, 0.3264, 0.5690, 0.6273, 0.4954])
# Iter:
# 395
# Inner prox iters used: 3
# Policy 1
# tensor([0.3866, 0.4264, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2259, 0.3264, 0.5690, 0.6273, 0.4954], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3866, 0.4264, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2259, 0.3264, 0.5690, 0.6273, 0.4954], grad_fn=<SqueezeBackward1>)
# tensor(0.2861, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2259, 0.3264, 0.5690, 0.6273, 0.4954])
# Curr pol
# tensor([0.2258, 0.3265, 0.5690, 0.6273, 0.4953])
# Iter:
# 396
# Inner prox iters used: 11
# Policy 1
# tensor([0.3867, 0.4265, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2258, 0.3265, 0.5690, 0.6273, 0.4953], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3867, 0.4265, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2258, 0.3265, 0.5690, 0.6273, 0.4953], grad_fn=<SqueezeBackward1>)
# tensor(0.2862, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2258, 0.3265, 0.5690, 0.6273, 0.4953])
# Curr pol
# tensor([0.2257, 0.3266, 0.5690, 0.6273, 0.4952])
# Iter:
# 397
# Inner prox iters used: 10
# Policy 1
# tensor([0.3868, 0.4266, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2257, 0.3266, 0.5690, 0.6273, 0.4952], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3868, 0.4266, 0.4183, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2257, 0.3266, 0.5690, 0.6273, 0.4952], grad_fn=<SqueezeBackward1>)
# tensor(0.2863, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2257, 0.3266, 0.5690, 0.6273, 0.4952])
# Curr pol
# tensor([0.2256, 0.3267, 0.5689, 0.6274, 0.4951])
# Iter:
# 398
# Inner prox iters used: 13
# Policy 1
# tensor([0.3870, 0.4266, 0.4184, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2256, 0.3267, 0.5689, 0.6274, 0.4951], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3870, 0.4266, 0.4184, 0.4380, 0.4885], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2256, 0.3267, 0.5689, 0.6274, 0.4951], grad_fn=<SqueezeBackward1>)
# tensor(0.2864, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2256, 0.3267, 0.5689, 0.6274, 0.4951])
# Curr pol
# tensor([0.2254, 0.3269, 0.5689, 0.6274, 0.4950])
# Iter:
# 399
# Inner prox iters used: 28
# Policy 1
# tensor([0.3872, 0.4268, 0.4184, 0.4380, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2254, 0.3269, 0.5689, 0.6274, 0.4950], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3872, 0.4268, 0.4184, 0.4380, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2254, 0.3269, 0.5689, 0.6274, 0.4950], grad_fn=<SqueezeBackward1>)
# tensor(0.2865, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2254, 0.3269, 0.5689, 0.6274, 0.4950])
# Curr pol
# tensor([0.2250, 0.3264, 0.5683, 0.6270, 0.4943])
# Iter:
# 400
# Inner prox iters used: 29
# Policy 1
# tensor([0.3875, 0.4269, 0.4184, 0.4380, 0.4883], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2250, 0.3264, 0.5683, 0.6270, 0.4943], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3875, 0.4269, 0.4184, 0.4380, 0.4883], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2250, 0.3264, 0.5683, 0.6270, 0.4943], grad_fn=<SqueezeBackward1>)
# tensor(0.2873, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2250, 0.3264, 0.5683, 0.6270, 0.4943])
# Curr pol
# tensor([0.2249, 0.3265, 0.5684, 0.6271, 0.4942])
# Iter:
# 401
# Inner prox iters used: 14
# Policy 1
# tensor([0.3876, 0.4270, 0.4184, 0.4380, 0.4883], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2249, 0.3265, 0.5684, 0.6271, 0.4942], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3876, 0.4270, 0.4184, 0.4380, 0.4883], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2249, 0.3265, 0.5684, 0.6271, 0.4942], grad_fn=<SqueezeBackward1>)
# tensor(0.2874, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2249, 0.3265, 0.5684, 0.6271, 0.4942])
# Curr pol
# tensor([0.2248, 0.3266, 0.5684, 0.6272, 0.4941])
# Iter:
# 402
# Inner prox iters used: 52
# Policy 1
# tensor([0.3880, 0.4272, 0.4185, 0.4380, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2248, 0.3266, 0.5684, 0.6272, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3880, 0.4272, 0.4185, 0.4380, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2248, 0.3266, 0.5684, 0.6272, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0.2875, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2248, 0.3266, 0.5684, 0.6272, 0.4941])
# Curr pol
# tensor([0.2247, 0.3269, 0.5684, 0.6273, 0.4941])
# Iter:
# 403
# Inner prox iters used: 8
# Policy 1
# tensor([0.3881, 0.4272, 0.4185, 0.4380, 0.4881], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2247, 0.3269, 0.5684, 0.6273, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3881, 0.4272, 0.4185, 0.4380, 0.4881], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2247, 0.3269, 0.5684, 0.6273, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0.2874, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2247, 0.3269, 0.5684, 0.6273, 0.4941])
# Curr pol
# tensor([0.2244, 0.3268, 0.5687, 0.6277, 0.4943])
# Iter:
# 404
# Inner prox iters used: 5
# Policy 1
# tensor([0.3881, 0.4272, 0.4185, 0.4380, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2244, 0.3268, 0.5687, 0.6277, 0.4943], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3881, 0.4272, 0.4185, 0.4380, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2244, 0.3268, 0.5687, 0.6277, 0.4943], grad_fn=<SqueezeBackward1>)
# tensor(0.2883, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2244, 0.3268, 0.5687, 0.6277, 0.4943])
# Curr pol
# tensor([0.2243, 0.3270, 0.5687, 0.6278, 0.4942])
# Iter:
# 405
# Inner prox iters used: 5
# Policy 1
# tensor([0.3882, 0.4273, 0.4185, 0.4380, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2243, 0.3270, 0.5687, 0.6278, 0.4942], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3882, 0.4273, 0.4185, 0.4380, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2243, 0.3270, 0.5687, 0.6278, 0.4942], grad_fn=<SqueezeBackward1>)
# tensor(0.2884, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2243, 0.3270, 0.5687, 0.6278, 0.4942])
# Curr pol
# tensor([0.2242, 0.3271, 0.5686, 0.6278, 0.4941])
# Iter:
# 406
# Inner prox iters used: 12
# Policy 1
# tensor([0.3883, 0.4274, 0.4186, 0.4381, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2242, 0.3271, 0.5686, 0.6278, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3883, 0.4274, 0.4186, 0.4381, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2242, 0.3271, 0.5686, 0.6278, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0.2884, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2242, 0.3271, 0.5686, 0.6278, 0.4941])
# Curr pol
# tensor([0.2241, 0.3273, 0.5686, 0.6278, 0.4940])
# Iter:
# 407
# Inner prox iters used: 7
# Policy 1
# tensor([0.3884, 0.4274, 0.4186, 0.4381, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2241, 0.3273, 0.5686, 0.6278, 0.4940], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3884, 0.4274, 0.4186, 0.4381, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2241, 0.3273, 0.5686, 0.6278, 0.4940], grad_fn=<SqueezeBackward1>)
# tensor(0.2884, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2241, 0.3273, 0.5686, 0.6278, 0.4940])
# Curr pol
# tensor([0.2239, 0.3274, 0.5686, 0.6280, 0.4940])
# Iter:
# 408
# Inner prox iters used: 44
# Policy 1
# tensor([0.3889, 0.4277, 0.4188, 0.4382, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2239, 0.3274, 0.5686, 0.6280, 0.4940], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3889, 0.4277, 0.4188, 0.4382, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2239, 0.3274, 0.5686, 0.6280, 0.4940], grad_fn=<SqueezeBackward1>)
# tensor(0.2887, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2239, 0.3274, 0.5686, 0.6280, 0.4940])
# Curr pol
# tensor([0.2238, 0.3275, 0.5686, 0.6280, 0.4939])
# Iter:
# 409
# Inner prox iters used: 6
# Policy 1
# tensor([0.3889, 0.4277, 0.4188, 0.4382, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2238, 0.3275, 0.5686, 0.6280, 0.4939], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3889, 0.4277, 0.4188, 0.4382, 0.4882], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2238, 0.3275, 0.5686, 0.6280, 0.4939], grad_fn=<SqueezeBackward1>)
# tensor(0.2888, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2238, 0.3275, 0.5686, 0.6280, 0.4939])
# Curr pol
# tensor([0.2237, 0.3276, 0.5686, 0.6280, 0.4938])
# Iter:
# 410
# Inner prox iters used: 14
# Policy 1
# tensor([0.3890, 0.4278, 0.4188, 0.4382, 0.4881], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2237, 0.3276, 0.5686, 0.6280, 0.4938], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3890, 0.4278, 0.4188, 0.4382, 0.4881], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2237, 0.3276, 0.5686, 0.6280, 0.4938], grad_fn=<SqueezeBackward1>)
# tensor(0.2889, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2237, 0.3276, 0.5686, 0.6280, 0.4938])
# Curr pol
# tensor([0.2209, 0.3276, 0.5751, 0.6374, 0.4978])
# Iter:
# 411
# Inner prox iters used: 126
# Policy 1
# tensor([0.3944, 0.4323, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2209, 0.3276, 0.5751, 0.6374, 0.4978], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3944, 0.4323, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2209, 0.3276, 0.5751, 0.6374, 0.4978], grad_fn=<SqueezeBackward1>)
# tensor(0.3007, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2209, 0.3276, 0.5751, 0.6374, 0.4978])
# Curr pol
# tensor([0.2208, 0.3276, 0.5748, 0.6372, 0.4974])
# Iter:
# 412
# Inner prox iters used: 4
# Policy 1
# tensor([0.3945, 0.4324, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2208, 0.3276, 0.5748, 0.6372, 0.4974], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3945, 0.4324, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2208, 0.3276, 0.5748, 0.6372, 0.4974], grad_fn=<SqueezeBackward1>)
# tensor(0.3007, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2208, 0.3276, 0.5748, 0.6372, 0.4974])
# Curr pol
# tensor([0.2206, 0.3276, 0.5745, 0.6370, 0.4971])
# Iter:
# 413
# Inner prox iters used: 2
# Policy 1
# tensor([0.3945, 0.4324, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2206, 0.3276, 0.5745, 0.6370, 0.4971], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3945, 0.4324, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2206, 0.3276, 0.5745, 0.6370, 0.4971], grad_fn=<SqueezeBackward1>)
# tensor(0.3007, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2206, 0.3276, 0.5745, 0.6370, 0.4971])
# Curr pol
# tensor([0.2204, 0.3276, 0.5742, 0.6368, 0.4968])
# Iter:
# 414
# Inner prox iters used: 2
# Policy 1
# tensor([0.3945, 0.4324, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2204, 0.3276, 0.5742, 0.6368, 0.4968], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3945, 0.4324, 0.4227, 0.4415, 0.4909], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2204, 0.3276, 0.5742, 0.6368, 0.4968], grad_fn=<SqueezeBackward1>)
# tensor(0.3007, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2204, 0.3276, 0.5742, 0.6368, 0.4968])
# Curr pol
# tensor([0.2203, 0.3276, 0.5739, 0.6366, 0.4965])
# Iter:
# 415
# Inner prox iters used: 21
# Policy 1
# tensor([0.3948, 0.4326, 0.4228, 0.4414, 0.4908], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2203, 0.3276, 0.5739, 0.6366, 0.4965], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3948, 0.4326, 0.4228, 0.4414, 0.4908], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2203, 0.3276, 0.5739, 0.6366, 0.4965], grad_fn=<SqueezeBackward1>)
# tensor(0.3008, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2203, 0.3276, 0.5739, 0.6366, 0.4965])
# Curr pol
# tensor([0.2201, 0.3277, 0.5736, 0.6364, 0.4962])
# Iter:
# 416
# Inner prox iters used: 3
# Policy 1
# tensor([0.3949, 0.4326, 0.4228, 0.4414, 0.4908], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2201, 0.3277, 0.5736, 0.6364, 0.4962], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3949, 0.4326, 0.4228, 0.4414, 0.4908], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2201, 0.3277, 0.5736, 0.6364, 0.4962], grad_fn=<SqueezeBackward1>)
# tensor(0.3008, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2201, 0.3277, 0.5736, 0.6364, 0.4962])
# Curr pol
# tensor([0.2200, 0.3278, 0.5734, 0.6364, 0.4960])
# Iter:
# 417
# Inner prox iters used: 32
# Policy 1
# tensor([0.3952, 0.4327, 0.4228, 0.4413, 0.4906], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2200, 0.3278, 0.5734, 0.6364, 0.4960], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3952, 0.4327, 0.4228, 0.4413, 0.4906], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2200, 0.3278, 0.5734, 0.6364, 0.4960], grad_fn=<SqueezeBackward1>)
# tensor(0.3009, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2200, 0.3278, 0.5734, 0.6364, 0.4960])
# Curr pol
# tensor([0.2199, 0.3278, 0.5732, 0.6362, 0.4957])
# Iter:
# 418
# Inner prox iters used: 4
# Policy 1
# tensor([0.3953, 0.4327, 0.4228, 0.4413, 0.4906], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2199, 0.3278, 0.5732, 0.6362, 0.4957], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3953, 0.4327, 0.4228, 0.4413, 0.4906], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2199, 0.3278, 0.5732, 0.6362, 0.4957], grad_fn=<SqueezeBackward1>)
# tensor(0.3009, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2199, 0.3278, 0.5732, 0.6362, 0.4957])
# Curr pol
# tensor([0.2197, 0.3277, 0.5730, 0.6361, 0.4955])
# Iter:
# 419
# Inner prox iters used: 19
# Policy 1
# tensor([0.3955, 0.4328, 0.4227, 0.4412, 0.4905], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2197, 0.3277, 0.5730, 0.6361, 0.4955], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3955, 0.4328, 0.4227, 0.4412, 0.4905], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2197, 0.3277, 0.5730, 0.6361, 0.4955], grad_fn=<SqueezeBackward1>)
# tensor(0.3012, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2197, 0.3277, 0.5730, 0.6361, 0.4955])
# Curr pol
# tensor([0.2196, 0.3278, 0.5728, 0.6360, 0.4952])
# Iter:
# 420
# Inner prox iters used: 5
# Policy 1
# tensor([0.3955, 0.4328, 0.4227, 0.4412, 0.4905], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2196, 0.3278, 0.5728, 0.6360, 0.4952], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3955, 0.4328, 0.4227, 0.4412, 0.4905], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2196, 0.3278, 0.5728, 0.6360, 0.4952], grad_fn=<SqueezeBackward1>)
# tensor(0.3011, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2196, 0.3278, 0.5728, 0.6360, 0.4952])
# Curr pol
# tensor([0.2195, 0.3279, 0.5725, 0.6358, 0.4950])
# Iter:
# 421
# Inner prox iters used: 1
# Policy 1
# tensor([0.3955, 0.4328, 0.4227, 0.4412, 0.4905], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2195, 0.3279, 0.5725, 0.6358, 0.4950], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3955, 0.4328, 0.4227, 0.4412, 0.4905], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2195, 0.3279, 0.5725, 0.6358, 0.4950], grad_fn=<SqueezeBackward1>)
# tensor(0.3011, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2195, 0.3279, 0.5725, 0.6358, 0.4950])
# Curr pol
# tensor([0.2194, 0.3281, 0.5723, 0.6357, 0.4947])
# Iter:
# 422
# Inner prox iters used: 22
# Policy 1
# tensor([0.3957, 0.4329, 0.4227, 0.4410, 0.4903], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2194, 0.3281, 0.5723, 0.6357, 0.4947], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3957, 0.4329, 0.4227, 0.4410, 0.4903], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2194, 0.3281, 0.5723, 0.6357, 0.4947], grad_fn=<SqueezeBackward1>)
# tensor(0.3009, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2194, 0.3281, 0.5723, 0.6357, 0.4947])
# Curr pol
# tensor([0.2193, 0.3282, 0.5721, 0.6356, 0.4945])
# Iter:
# 423
# Inner prox iters used: 1
# Policy 1
# tensor([0.3957, 0.4329, 0.4227, 0.4410, 0.4903], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2193, 0.3282, 0.5721, 0.6356, 0.4945], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3957, 0.4329, 0.4227, 0.4410, 0.4903], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2193, 0.3282, 0.5721, 0.6356, 0.4945], grad_fn=<SqueezeBackward1>)
# tensor(0.3010, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2193, 0.3282, 0.5721, 0.6356, 0.4945])
# Curr pol
# tensor([0.2191, 0.3282, 0.5720, 0.6355, 0.4943])
# Iter:
# 424
# Inner prox iters used: 1
# Policy 1
# tensor([0.3957, 0.4329, 0.4227, 0.4410, 0.4903], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2191, 0.3282, 0.5720, 0.6355, 0.4943], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3957, 0.4329, 0.4227, 0.4410, 0.4903], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2191, 0.3282, 0.5720, 0.6355, 0.4943], grad_fn=<SqueezeBackward1>)
# tensor(0.3011, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2191, 0.3282, 0.5720, 0.6355, 0.4943])
# Curr pol
# tensor([0.2190, 0.3283, 0.5718, 0.6354, 0.4941])
# Iter:
# 425
# Inner prox iters used: 19
# Policy 1
# tensor([0.3958, 0.4329, 0.4226, 0.4409, 0.4901], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2190, 0.3283, 0.5718, 0.6354, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3958, 0.4329, 0.4226, 0.4409, 0.4901], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2190, 0.3283, 0.5718, 0.6354, 0.4941], grad_fn=<SqueezeBackward1>)
# tensor(0.3010, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2190, 0.3283, 0.5718, 0.6354, 0.4941])
# Curr pol
# tensor([0.2189, 0.3284, 0.5716, 0.6353, 0.4939])
# Iter:
# 426
# Inner prox iters used: 14
# Policy 1
# tensor([0.3959, 0.4329, 0.4226, 0.4409, 0.4900], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2189, 0.3284, 0.5716, 0.6353, 0.4939], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3959, 0.4329, 0.4226, 0.4409, 0.4900], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2189, 0.3284, 0.5716, 0.6353, 0.4939], grad_fn=<SqueezeBackward1>)
# tensor(0.3010, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2189, 0.3284, 0.5716, 0.6353, 0.4939])
# Curr pol
# tensor([0.2186, 0.3283, 0.5714, 0.6353, 0.4938])
# Iter:
# 427
# Inner prox iters used: 19
# Policy 1
# tensor([0.3961, 0.4329, 0.4225, 0.4408, 0.4899], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2186, 0.3283, 0.5714, 0.6353, 0.4938], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3961, 0.4329, 0.4225, 0.4408, 0.4899], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2186, 0.3283, 0.5714, 0.6353, 0.4938], grad_fn=<SqueezeBackward1>)
# tensor(0.3015, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2186, 0.3283, 0.5714, 0.6353, 0.4938])
# Curr pol
# tensor([0.2186, 0.3284, 0.5713, 0.6352, 0.4936])
# Iter:
# 428
# Inner prox iters used: 1
# Policy 1
# tensor([0.3961, 0.4329, 0.4225, 0.4408, 0.4899], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2186, 0.3284, 0.5713, 0.6352, 0.4936], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3961, 0.4329, 0.4225, 0.4408, 0.4899], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2186, 0.3284, 0.5713, 0.6352, 0.4936], grad_fn=<SqueezeBackward1>)
# tensor(0.3014, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2186, 0.3284, 0.5713, 0.6352, 0.4936])
# Curr pol
# tensor([0.2185, 0.3286, 0.5711, 0.6351, 0.4934])
# Iter:
# 429
# Inner prox iters used: 11
# Policy 1
# tensor([0.3962, 0.4330, 0.4225, 0.4407, 0.4899], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2185, 0.3286, 0.5711, 0.6351, 0.4934], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3962, 0.4330, 0.4225, 0.4407, 0.4899], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2185, 0.3286, 0.5711, 0.6351, 0.4934], grad_fn=<SqueezeBackward1>)
# tensor(0.3014, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2185, 0.3286, 0.5711, 0.6351, 0.4934])
# Curr pol
# tensor([0.2184, 0.3287, 0.5709, 0.6350, 0.4932])
# Iter:
# 430
# Inner prox iters used: 5
# Policy 1
# tensor([0.3962, 0.4330, 0.4225, 0.4407, 0.4898], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2184, 0.3287, 0.5709, 0.6350, 0.4932], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3962, 0.4330, 0.4225, 0.4407, 0.4898], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2184, 0.3287, 0.5709, 0.6350, 0.4932], grad_fn=<SqueezeBackward1>)
# tensor(0.3013, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2184, 0.3287, 0.5709, 0.6350, 0.4932])
# Curr pol
# tensor([0.2184, 0.3289, 0.5707, 0.6348, 0.4930])
# Iter:
# 431
# Inner prox iters used: 19
# Policy 1
# tensor([0.3963, 0.4329, 0.4224, 0.4406, 0.4897], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2184, 0.3289, 0.5707, 0.6348, 0.4930], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3963, 0.4329, 0.4224, 0.4406, 0.4897], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2184, 0.3289, 0.5707, 0.6348, 0.4930], grad_fn=<SqueezeBackward1>)
# tensor(0.3009, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2184, 0.3289, 0.5707, 0.6348, 0.4930])
# Curr pol
# tensor([0.2183, 0.3290, 0.5707, 0.6349, 0.4929])
# Iter:
# 432
# Inner prox iters used: 13
# Policy 1
# tensor([0.3963, 0.4329, 0.4224, 0.4406, 0.4896], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2183, 0.3290, 0.5707, 0.6349, 0.4929], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3963, 0.4329, 0.4224, 0.4406, 0.4896], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2183, 0.3290, 0.5707, 0.6349, 0.4929], grad_fn=<SqueezeBackward1>)
# tensor(0.3011, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2183, 0.3290, 0.5707, 0.6349, 0.4929])
# Curr pol
# tensor([0.2182, 0.3291, 0.5706, 0.6348, 0.4927])
# Iter:
# 433
# Inner prox iters used: 4
# Policy 1
# tensor([0.3964, 0.4329, 0.4224, 0.4405, 0.4896], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2182, 0.3291, 0.5706, 0.6348, 0.4927], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3964, 0.4329, 0.4224, 0.4405, 0.4896], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2182, 0.3291, 0.5706, 0.6348, 0.4927], grad_fn=<SqueezeBackward1>)
# tensor(0.3011, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2182, 0.3291, 0.5706, 0.6348, 0.4927])
# Curr pol
# tensor([0.2181, 0.3292, 0.5705, 0.6348, 0.4926])
# Iter:
# 434
# Inner prox iters used: 3
# Policy 1
# tensor([0.3964, 0.4329, 0.4224, 0.4405, 0.4896], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2181, 0.3292, 0.5705, 0.6348, 0.4926], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3964, 0.4329, 0.4224, 0.4405, 0.4896], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2181, 0.3292, 0.5705, 0.6348, 0.4926], grad_fn=<SqueezeBackward1>)
# tensor(0.3012, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2181, 0.3292, 0.5705, 0.6348, 0.4926])
# Curr pol
# tensor([0.2180, 0.3293, 0.5703, 0.6347, 0.4924])
# Iter:
# 435
# Inner prox iters used: 13
# Policy 1
# tensor([0.3965, 0.4329, 0.4223, 0.4405, 0.4895], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2180, 0.3293, 0.5703, 0.6347, 0.4924], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3965, 0.4329, 0.4223, 0.4405, 0.4895], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2180, 0.3293, 0.5703, 0.6347, 0.4924], grad_fn=<SqueezeBackward1>)
# tensor(0.3011, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2180, 0.3293, 0.5703, 0.6347, 0.4924])
# Curr pol
# tensor([0.2180, 0.3295, 0.5702, 0.6346, 0.4923])
# Iter:
# 436
# Inner prox iters used: 56
# Policy 1
# tensor([0.3967, 0.4330, 0.4222, 0.4403, 0.4892], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2180, 0.3295, 0.5702, 0.6346, 0.4923], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4330, 0.4222, 0.4403, 0.4892], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2180, 0.3295, 0.5702, 0.6346, 0.4923], grad_fn=<SqueezeBackward1>)
# tensor(0.3009, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2180, 0.3295, 0.5702, 0.6346, 0.4923])
# Curr pol
# tensor([0.2179, 0.3292, 0.5690, 0.6336, 0.4915])
# Iter:
# 437
# Inner prox iters used: 7
# Policy 1
# tensor([0.3967, 0.4329, 0.4222, 0.4402, 0.4891], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2179, 0.3292, 0.5690, 0.6336, 0.4915], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4329, 0.4222, 0.4402, 0.4891], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2179, 0.3292, 0.5690, 0.6336, 0.4915], grad_fn=<SqueezeBackward1>)
# tensor(0.3004, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2179, 0.3292, 0.5690, 0.6336, 0.4915])
# Curr pol
# tensor([0.2179, 0.3293, 0.5689, 0.6335, 0.4913])
# Iter:
# 438
# Inner prox iters used: 8
# Policy 1
# tensor([0.3967, 0.4329, 0.4221, 0.4401, 0.4890], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2179, 0.3293, 0.5689, 0.6335, 0.4913], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4329, 0.4221, 0.4401, 0.4890], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2179, 0.3293, 0.5689, 0.6335, 0.4913], grad_fn=<SqueezeBackward1>)
# tensor(0.3003, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2179, 0.3293, 0.5689, 0.6335, 0.4913])
# Curr pol
# tensor([0.2178, 0.3295, 0.5688, 0.6335, 0.4912])
# Iter:
# 439
# Inner prox iters used: 3
# Policy 1
# tensor([0.3967, 0.4328, 0.4221, 0.4401, 0.4890], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2178, 0.3295, 0.5688, 0.6335, 0.4912], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4328, 0.4221, 0.4401, 0.4890], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2178, 0.3295, 0.5688, 0.6335, 0.4912], grad_fn=<SqueezeBackward1>)
# tensor(0.3003, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2178, 0.3295, 0.5688, 0.6335, 0.4912])
# Curr pol
# tensor([0.2177, 0.3297, 0.5687, 0.6335, 0.4911])
# Iter:
# 440
# Inner prox iters used: 6
# Policy 1
# tensor([0.3967, 0.4328, 0.4220, 0.4401, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2177, 0.3297, 0.5687, 0.6335, 0.4911], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4328, 0.4220, 0.4401, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2177, 0.3297, 0.5687, 0.6335, 0.4911], grad_fn=<SqueezeBackward1>)
# tensor(0.3002, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2177, 0.3297, 0.5687, 0.6335, 0.4911])
# Curr pol
# tensor([0.2177, 0.3298, 0.5687, 0.6335, 0.4910])
# Iter:
# 441
# Inner prox iters used: 1
# Policy 1
# tensor([0.3967, 0.4328, 0.4220, 0.4401, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2177, 0.3298, 0.5687, 0.6335, 0.4910], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4328, 0.4220, 0.4401, 0.4889], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2177, 0.3298, 0.5687, 0.6335, 0.4910], grad_fn=<SqueezeBackward1>)
# tensor(0.3001, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2177, 0.3298, 0.5687, 0.6335, 0.4910])
# Curr pol
# tensor([0.2176, 0.3300, 0.5686, 0.6334, 0.4909])
# Iter:
# 442
# Inner prox iters used: 12
# Policy 1
# tensor([0.3967, 0.4328, 0.4220, 0.4400, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2176, 0.3300, 0.5686, 0.6334, 0.4909], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4328, 0.4220, 0.4400, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2176, 0.3300, 0.5686, 0.6334, 0.4909], grad_fn=<SqueezeBackward1>)
# tensor(0.3000, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2176, 0.3300, 0.5686, 0.6334, 0.4909])
# Curr pol
# tensor([0.2176, 0.3302, 0.5685, 0.6334, 0.4908])
# Iter:
# 443
# Inner prox iters used: 2
# Policy 1
# tensor([0.3967, 0.4327, 0.4219, 0.4400, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2176, 0.3302, 0.5685, 0.6334, 0.4908], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4327, 0.4219, 0.4400, 0.4888], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2176, 0.3302, 0.5685, 0.6334, 0.4908], grad_fn=<SqueezeBackward1>)
# tensor(0.3000, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2176, 0.3302, 0.5685, 0.6334, 0.4908])
# Curr pol
# tensor([0.2175, 0.3304, 0.5684, 0.6334, 0.4907])
# Iter:
# 444
# Inner prox iters used: 19
# Policy 1
# tensor([0.3967, 0.4327, 0.4218, 0.4399, 0.4887], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2175, 0.3304, 0.5684, 0.6334, 0.4907], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4327, 0.4218, 0.4399, 0.4887], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2175, 0.3304, 0.5684, 0.6334, 0.4907], grad_fn=<SqueezeBackward1>)
# tensor(0.2999, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2175, 0.3304, 0.5684, 0.6334, 0.4907])
# Curr pol
# tensor([0.2175, 0.3305, 0.5683, 0.6334, 0.4907])
# Iter:
# 445
# Inner prox iters used: 11
# Policy 1
# tensor([0.3967, 0.4326, 0.4218, 0.4398, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2175, 0.3305, 0.5683, 0.6334, 0.4907], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3967, 0.4326, 0.4218, 0.4398, 0.4886], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2175, 0.3305, 0.5683, 0.6334, 0.4907], grad_fn=<SqueezeBackward1>)
# tensor(0.2998, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2175, 0.3305, 0.5683, 0.6334, 0.4907])
# Curr pol
# tensor([0.2173, 0.3306, 0.5684, 0.6335, 0.4907])
# Iter:
# 446
# Inner prox iters used: 39
# Policy 1
# tensor([0.3968, 0.4326, 0.4217, 0.4397, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2173, 0.3306, 0.5684, 0.6335, 0.4907], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3968, 0.4326, 0.4217, 0.4397, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2173, 0.3306, 0.5684, 0.6335, 0.4907], grad_fn=<SqueezeBackward1>)
# tensor(0.3002, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2173, 0.3306, 0.5684, 0.6335, 0.4907])
# Curr pol
# tensor([0.2172, 0.3308, 0.5683, 0.6335, 0.4906])
# Iter:
# 447
# Inner prox iters used: 11
# Policy 1
# tensor([0.3969, 0.4326, 0.4217, 0.4397, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2172, 0.3308, 0.5683, 0.6335, 0.4906], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3969, 0.4326, 0.4217, 0.4397, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2172, 0.3308, 0.5683, 0.6335, 0.4906], grad_fn=<SqueezeBackward1>)
# tensor(0.3001, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2172, 0.3308, 0.5683, 0.6335, 0.4906])
# Curr pol
# tensor([0.2172, 0.3309, 0.5683, 0.6335, 0.4905])
# Iter:
# 448
# Inner prox iters used: 10
# Policy 1
# tensor([0.3969, 0.4326, 0.4217, 0.4397, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2172, 0.3309, 0.5683, 0.6335, 0.4905], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3969, 0.4326, 0.4217, 0.4397, 0.4884], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2172, 0.3309, 0.5683, 0.6335, 0.4905], grad_fn=<SqueezeBackward1>)
# tensor(0.3001, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2172, 0.3309, 0.5683, 0.6335, 0.4905])
# Curr pol
# tensor([0.2171, 0.3311, 0.5682, 0.6335, 0.4904])
# Iter:
# 449
# Inner prox iters used: 7
# Policy 1
# tensor([0.3969, 0.4326, 0.4217, 0.4397, 0.4883], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2171, 0.3311, 0.5682, 0.6335, 0.4904], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3969, 0.4326, 0.4217, 0.4397, 0.4883], grad_fn=<SqueezeBackward1>)
# Policy 2
# ...
# Policy 2
# tensor([0.2073, 0.3459, 0.5620, 0.6299, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3030, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2073, 0.3459, 0.5620, 0.6299, 0.4826])
# Curr pol
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826])
# Iter:
# 632
# Inner prox iters used: 17
# Policy 1
# tensor([0.4022, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4022, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3031, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826])
# Curr pol
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826])
# Iter:
# 633
# Inner prox iters used: 12
# Policy 1
# tensor([0.4022, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4022, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3031, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2072, 0.3459, 0.5620, 0.6298, 0.4826])
# Curr pol
# tensor([0.2072, 0.3460, 0.5620, 0.6298, 0.4826])
# Iter:
# 634
# Inner prox iters used: 2
# Policy 1
# tensor([0.4022, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2072, 0.3460, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4022, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2072, 0.3460, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3031, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2072, 0.3460, 0.5620, 0.6298, 0.4826])
# Curr pol
# tensor([0.2071, 0.3460, 0.5620, 0.6298, 0.4826])
# Iter:
# 635
# Inner prox iters used: 5
# Policy 1
# tensor([0.4023, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2071, 0.3460, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4023, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2071, 0.3460, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3032, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2071, 0.3460, 0.5620, 0.6298, 0.4826])
# Curr pol
# tensor([0.2071, 0.3461, 0.5619, 0.6298, 0.4826])
# Iter:
# 636
# Inner prox iters used: 6
# Policy 1
# tensor([0.4023, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2071, 0.3461, 0.5619, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4023, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2071, 0.3461, 0.5619, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3032, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2071, 0.3461, 0.5619, 0.6298, 0.4826])
# Curr pol
# tensor([0.2070, 0.3461, 0.5619, 0.6298, 0.4826])
# Iter:
# 637
# Inner prox iters used: 2
# Policy 1
# tensor([0.4023, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2070, 0.3461, 0.5619, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4023, 0.4331, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2070, 0.3461, 0.5619, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3033, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2070, 0.3461, 0.5619, 0.6298, 0.4826])
# Curr pol
# tensor([0.2068, 0.3459, 0.5621, 0.6300, 0.4827])
# Iter:
# 638
# Inner prox iters used: 13
# Policy 1
# tensor([0.4024, 0.4332, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2068, 0.3459, 0.5621, 0.6300, 0.4827], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4024, 0.4332, 0.4200, 0.4389, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2068, 0.3459, 0.5621, 0.6300, 0.4827], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2068, 0.3459, 0.5621, 0.6300, 0.4827])
# Curr pol
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827])
# Iter:
# 639
# Inner prox iters used: 13
# Policy 1
# tensor([0.4024, 0.4332, 0.4200, 0.4390, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4024, 0.4332, 0.4200, 0.4390, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827])
# Curr pol
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827])
# Iter:
# 640
# Inner prox iters used: 17
# Policy 1
# tensor([0.4025, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4025, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2067, 0.3460, 0.5621, 0.6300, 0.4827])
# Curr pol
# tensor([0.2067, 0.3460, 0.5620, 0.6299, 0.4826])
# Iter:
# 641
# Inner prox iters used: 18
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2067, 0.3460, 0.5620, 0.6299, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2067, 0.3460, 0.5620, 0.6299, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2067, 0.3460, 0.5620, 0.6299, 0.4826])
# Curr pol
# tensor([0.2066, 0.3461, 0.5620, 0.6299, 0.4826])
# Iter:
# 642
# Inner prox iters used: 11
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3461, 0.5620, 0.6299, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3461, 0.5620, 0.6299, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2066, 0.3461, 0.5620, 0.6299, 0.4826])
# Curr pol
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826])
# Iter:
# 643
# Inner prox iters used: 9
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826])
# Curr pol
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826])
# Iter:
# 644
# Inner prox iters used: 9
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4026, 0.4333, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826])
# Curr pol
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826])
# Iter:
# 645
# Inner prox iters used: 12
# Policy 1
# tensor([0.4027, 0.4334, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4027, 0.4334, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2066, 0.3462, 0.5620, 0.6298, 0.4826])
# Curr pol
# tensor([0.2065, 0.3463, 0.5620, 0.6298, 0.4825])
# Iter:
# 646
# Inner prox iters used: 5
# Policy 1
# tensor([0.4027, 0.4334, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2065, 0.3463, 0.5620, 0.6298, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4027, 0.4334, 0.4201, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2065, 0.3463, 0.5620, 0.6298, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2065, 0.3463, 0.5620, 0.6298, 0.4825])
# Curr pol
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825])
# Iter:
# 647
# Inner prox iters used: 23
# Policy 1
# tensor([0.4027, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4027, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825])
# Curr pol
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825])
# Iter:
# 648
# Inner prox iters used: 8
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2065, 0.3464, 0.5620, 0.6297, 0.4825])
# Curr pol
# tensor([0.2064, 0.3464, 0.5619, 0.6297, 0.4825])
# Iter:
# 649
# Inner prox iters used: 2
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2064, 0.3464, 0.5619, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2064, 0.3464, 0.5619, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2064, 0.3464, 0.5619, 0.6297, 0.4825])
# Curr pol
# tensor([0.2064, 0.3465, 0.5619, 0.6297, 0.4825])
# Iter:
# 650
# Inner prox iters used: 2
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2064, 0.3465, 0.5619, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2064, 0.3465, 0.5619, 0.6297, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2064, 0.3465, 0.5619, 0.6297, 0.4825])
# Curr pol
# tensor([0.2064, 0.3465, 0.5619, 0.6296, 0.4825])
# Iter:
# 651
# Inner prox iters used: 3
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2064, 0.3465, 0.5619, 0.6296, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2064, 0.3465, 0.5619, 0.6296, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2064, 0.3465, 0.5619, 0.6296, 0.4825])
# Curr pol
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825])
# Iter:
# 652
# Inner prox iters used: 4
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825])
# Curr pol
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825])
# Iter:
# 653
# Inner prox iters used: 17
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2063, 0.3466, 0.5619, 0.6296, 0.4825])
# Curr pol
# tensor([0.2063, 0.3467, 0.5619, 0.6296, 0.4824])
# Iter:
# 654
# Inner prox iters used: 2
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2063, 0.3467, 0.5619, 0.6296, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4028, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2063, 0.3467, 0.5619, 0.6296, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2063, 0.3467, 0.5619, 0.6296, 0.4824])
# Curr pol
# tensor([0.2062, 0.3467, 0.5619, 0.6295, 0.4824])
# Iter:
# 655
# Inner prox iters used: 11
# Policy 1
# tensor([0.4029, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3467, 0.5619, 0.6295, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4029, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3467, 0.5619, 0.6295, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2062, 0.3467, 0.5619, 0.6295, 0.4824])
# Curr pol
# tensor([0.2062, 0.3468, 0.5618, 0.6295, 0.4824])
# Iter:
# 656
# Inner prox iters used: 19
# Policy 1
# tensor([0.4029, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3468, 0.5618, 0.6295, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4029, 0.4334, 0.4200, 0.4390, 0.4866], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3468, 0.5618, 0.6295, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2062, 0.3468, 0.5618, 0.6295, 0.4824])
# Curr pol
# tensor([0.2062, 0.3468, 0.5618, 0.6294, 0.4824])
# Iter:
# 657
# Inner prox iters used: 40
# Policy 1
# tensor([0.4030, 0.4334, 0.4199, 0.4390, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3468, 0.5618, 0.6294, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4030, 0.4334, 0.4199, 0.4390, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3468, 0.5618, 0.6294, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2062, 0.3468, 0.5618, 0.6294, 0.4824])
# Curr pol
# tensor([0.2062, 0.3469, 0.5618, 0.6294, 0.4824])
# Iter:
# 658
# Inner prox iters used: 10
# Policy 1
# tensor([0.4030, 0.4334, 0.4199, 0.4390, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3469, 0.5618, 0.6294, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4030, 0.4334, 0.4199, 0.4390, 0.4865], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2062, 0.3469, 0.5618, 0.6294, 0.4824], grad_fn=<SqueezeBackward1>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2062, 0.3469, 0.5618, 0.6294, 0.4824])
# Curr pol
# tensor([0.2061, 0.3469, 0.5618, 0.6294, 0.4824])
# Iter:
# 659
# Outer prox iters used: 659
# Epoch: 1
# Time Elapsed: 2831.5 seconds
# Discounted Rewards: tensor([3.2379, 3.1976])
# Max Avg Coop Payout (Infinite Horizon): 8.250
# Policy 1
# tensor([0.2015, 0.5624, 0.3476, 0.6266, 0.4822], grad_fn=<SqueezeBackward1>)
# Policy 2
# tensor([0.2061, 0.3469, 0.5618, 0.6294, 0.4824], grad_fn=<SqueezeBackward1>)

# %%
# Tabular POLA
# !python LOLA_exact.py --n_agents 2 --print_every 1 --repeats 1 --num_epochs 1 --init_state_representation 2  --std 0  --lr_policies_inner 0.1 --lr_policies_outer .1 --set_seed --seed 1 --actual_update --base_cf_no_scale 1.33 --inner_exact_prox --inner_beta 2 --outer_exact_prox --outer_beta 5 --print_prox_loops_info
# Out:
# Number of agents: 2
# Contribution factor: 1.33
# Scaled contribution factor? False
# Exact Gradients
# Actual Update LOLA
# lr_policies_outer: tensor([0.1000, 0.1000])
# lr_policies_inner: tensor([0.1000, 0.1000])
# Starting Policies:
# Policy 1
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# Inner prox iters used: 132
# Policy 1
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2109, 0.3604, 0.2109, 0.3604, 0.4518], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2109, 0.3604, 0.2109, 0.3604, 0.4518], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000])
# Curr pol
# tensor([0.4627, 0.5123, 0.4627, 0.5123, 0.4979])
# Iter:
# 1
# Inner prox iters used: 93
# Policy 1
# tensor([0.4627, 0.5123, 0.4627, 0.5123, 0.4979], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2233, 0.3623, 0.2379, 0.3704, 0.4566], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4627, 0.5123, 0.4627, 0.5123, 0.4979], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2233, 0.3623, 0.2379, 0.3704, 0.4566], grad_fn=<SigmoidBackward0>)
# tensor(0.0062, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.4627, 0.5123, 0.4627, 0.5123, 0.4979])
# Curr pol
# tensor([0.4271, 0.5245, 0.4338, 0.5237, 0.4962])
# Iter:
# 2
# Inner prox iters used: 97
# Policy 1
# tensor([0.4271, 0.5245, 0.4338, 0.5237, 0.4962], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2384, 0.3650, 0.2650, 0.3793, 0.4612], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4271, 0.5245, 0.4338, 0.5237, 0.4962], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2384, 0.3650, 0.2650, 0.3793, 0.4612], grad_fn=<SigmoidBackward0>)
# tensor(0.0219, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.4271, 0.5245, 0.4338, 0.5237, 0.4962])
# Curr pol
# tensor([0.3941, 0.5365, 0.4118, 0.5344, 0.4947])
# Iter:
# 3
# Inner prox iters used: 81
# Policy 1
# tensor([0.3941, 0.5365, 0.4118, 0.5344, 0.4947], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2548, 0.3687, 0.2903, 0.3876, 0.4652], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3941, 0.5365, 0.4118, 0.5344, 0.4947], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2548, 0.3687, 0.2903, 0.3876, 0.4652], grad_fn=<SigmoidBackward0>)
# tensor(0.0439, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3941, 0.5365, 0.4118, 0.5344, 0.4947])
# Curr pol
# tensor([0.3638, 0.5479, 0.3954, 0.5442, 0.4934])
# Iter:
# 4
# Inner prox iters used: 104
# Policy 1
# tensor([0.3638, 0.5479, 0.3954, 0.5442, 0.4934], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2735, 0.3729, 0.3146, 0.3951, 0.4689], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3638, 0.5479, 0.3954, 0.5442, 0.4934], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2735, 0.3729, 0.3146, 0.3951, 0.4689], grad_fn=<SigmoidBackward0>)
# tensor(0.0695, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3638, 0.5479, 0.3954, 0.5442, 0.4934])
# Curr pol
# tensor([0.3368, 0.5584, 0.3833, 0.5532, 0.4924])
# Iter:
# 5
# Inner prox iters used: 73
# Policy 1
# tensor([0.3368, 0.5584, 0.3833, 0.5532, 0.4924], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2918, 0.3777, 0.3354, 0.4020, 0.4719], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3368, 0.5584, 0.3833, 0.5532, 0.4924], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2918, 0.3777, 0.3354, 0.4020, 0.4719], grad_fn=<SigmoidBackward0>)
# tensor(0.0970, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3368, 0.5584, 0.3833, 0.5532, 0.4924])
# Curr pol
# tensor([0.3130, 0.5677, 0.3746, 0.5612, 0.4914])
# Iter:
# 6
# Inner prox iters used: 92
# Policy 1
# tensor([0.3130, 0.5677, 0.3746, 0.5612, 0.4914], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3115, 0.3823, 0.3547, 0.4081, 0.4748], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3130, 0.5677, 0.3746, 0.5612, 0.4914], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3115, 0.3823, 0.3547, 0.4081, 0.4748], grad_fn=<SigmoidBackward0>)
# tensor(0.1248, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3130, 0.5677, 0.3746, 0.5612, 0.4914])
# Curr pol
# tensor([0.2926, 0.5754, 0.3683, 0.5682, 0.4906])
# Iter:
# 7
# Inner prox iters used: 76
# Policy 1
# tensor([0.2926, 0.5754, 0.3683, 0.5682, 0.4906], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3293, 0.3868, 0.3704, 0.4134, 0.4770], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2926, 0.5754, 0.3683, 0.5682, 0.4906], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3293, 0.3868, 0.3704, 0.4134, 0.4770], grad_fn=<SigmoidBackward0>)
# tensor(0.1515, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2926, 0.5754, 0.3683, 0.5682, 0.4906])
# Curr pol
# tensor([0.2754, 0.5813, 0.3638, 0.5740, 0.4899])
# Iter:
# 8
# Inner prox iters used: 83
# Policy 1
# tensor([0.2754, 0.5813, 0.3638, 0.5740, 0.4899], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3459, 0.3909, 0.3836, 0.4178, 0.4789], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2754, 0.5813, 0.3638, 0.5740, 0.4899], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3459, 0.3909, 0.3836, 0.4178, 0.4789], grad_fn=<SigmoidBackward0>)
# tensor(0.1760, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2754, 0.5813, 0.3638, 0.5740, 0.4899])
# Curr pol
# tensor([0.2612, 0.5855, 0.3607, 0.5788, 0.4892])
# Iter:
# 9
# Inner prox iters used: 73
# Policy 1
# tensor([0.2612, 0.5855, 0.3607, 0.5788, 0.4892], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3596, 0.3943, 0.3939, 0.4215, 0.4804], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2612, 0.5855, 0.3607, 0.5788, 0.4892], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3596, 0.3943, 0.3939, 0.4215, 0.4804], grad_fn=<SigmoidBackward0>)
# tensor(0.1975, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2612, 0.5855, 0.3607, 0.5788, 0.4892])
# Curr pol
# tensor([0.2496, 0.5881, 0.3586, 0.5827, 0.4886])
# Iter:
# 10
# Inner prox iters used: 60
# Policy 1
# tensor([0.2496, 0.5881, 0.3586, 0.5827, 0.4886], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3706, 0.3973, 0.4018, 0.4245, 0.4815], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2496, 0.5881, 0.3586, 0.5827, 0.4886], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3706, 0.3973, 0.4018, 0.4245, 0.4815], grad_fn=<SigmoidBackward0>)
# tensor(0.2160, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2496, 0.5881, 0.3586, 0.5827, 0.4886])
# Curr pol
# tensor([0.2402, 0.5895, 0.3571, 0.5857, 0.4880])
# Iter:
# 11
# Inner prox iters used: 56
# Policy 1
# tensor([0.2402, 0.5895, 0.3571, 0.5857, 0.4880], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3796, 0.3996, 0.4080, 0.4269, 0.4824], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2402, 0.5895, 0.3571, 0.5857, 0.4880], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3796, 0.3996, 0.4080, 0.4269, 0.4824], grad_fn=<SigmoidBackward0>)
# tensor(0.2314, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2402, 0.5895, 0.3571, 0.5857, 0.4880])
# Curr pol
# tensor([0.2327, 0.5899, 0.3561, 0.5881, 0.4875])
# Iter:
# 12
# Inner prox iters used: 46
# Policy 1
# tensor([0.2327, 0.5899, 0.3561, 0.5881, 0.4875], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3863, 0.4015, 0.4127, 0.4288, 0.4831], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2327, 0.5899, 0.3561, 0.5881, 0.4875], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3863, 0.4015, 0.4127, 0.4288, 0.4831], grad_fn=<SigmoidBackward0>)
# tensor(0.2441, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2327, 0.5899, 0.3561, 0.5881, 0.4875])
# Curr pol
# tensor([0.2266, 0.5896, 0.3555, 0.5900, 0.4870])
# Iter:
# 13
# Inner prox iters used: 47
# Policy 1
# tensor([0.2266, 0.5896, 0.3555, 0.5900, 0.4870], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3920, 0.4030, 0.4164, 0.4303, 0.4837], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2266, 0.5896, 0.3555, 0.5900, 0.4870], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3920, 0.4030, 0.4164, 0.4303, 0.4837], grad_fn=<SigmoidBackward0>)
# tensor(0.2544, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2266, 0.5896, 0.3555, 0.5900, 0.4870])
# Curr pol
# tensor([0.2216, 0.5889, 0.3551, 0.5915, 0.4865])
# Iter:
# 14
# Inner prox iters used: 49
# Policy 1
# tensor([0.2216, 0.5889, 0.3551, 0.5915, 0.4865], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3964, 0.4042, 0.4194, 0.4315, 0.4841], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2216, 0.5889, 0.3551, 0.5915, 0.4865], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3964, 0.4042, 0.4194, 0.4315, 0.4841], grad_fn=<SigmoidBackward0>)
# tensor(0.2629, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2216, 0.5889, 0.3551, 0.5915, 0.4865])
# Curr pol
# tensor([0.2176, 0.5878, 0.3549, 0.5927, 0.4861])
# Iter:
# 15
# Inner prox iters used: 62
# Policy 1
# tensor([0.2176, 0.5878, 0.3549, 0.5927, 0.4861], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3999, 0.4052, 0.4217, 0.4325, 0.4844], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2176, 0.5878, 0.3549, 0.5927, 0.4861], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3999, 0.4052, 0.4217, 0.4325, 0.4844], grad_fn=<SigmoidBackward0>)
# tensor(0.2697, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2176, 0.5878, 0.3549, 0.5927, 0.4861])
# Curr pol
# tensor([0.2142, 0.5865, 0.3548, 0.5937, 0.4858])
# Iter:
# 16
# Inner prox iters used: 24
# Policy 1
# tensor([0.2142, 0.5865, 0.3548, 0.5937, 0.4858], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4016, 0.4058, 0.4229, 0.4331, 0.4846], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2142, 0.5865, 0.3548, 0.5937, 0.4858], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4016, 0.4058, 0.4229, 0.4331, 0.4846], grad_fn=<SigmoidBackward0>)
# tensor(0.2753, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2142, 0.5865, 0.3548, 0.5937, 0.4858])
# Curr pol
# tensor([0.2114, 0.5853, 0.3548, 0.5944, 0.4854])
# Iter:
# 17
# Inner prox iters used: 26
# Policy 1
# tensor([0.2114, 0.5853, 0.3548, 0.5944, 0.4854], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4035, 0.4064, 0.4242, 0.4337, 0.4848], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2114, 0.5853, 0.3548, 0.5944, 0.4854], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4035, 0.4064, 0.4242, 0.4337, 0.4848], grad_fn=<SigmoidBackward0>)
# tensor(0.2799, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2114, 0.5853, 0.3548, 0.5944, 0.4854])
# Curr pol
# tensor([0.2091, 0.5840, 0.3549, 0.5951, 0.4851])
# Iter:
# 18
# Inner prox iters used: 20
# Policy 1
# tensor([0.2091, 0.5840, 0.3549, 0.5951, 0.4851], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4049, 0.4069, 0.4252, 0.4342, 0.4849], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2091, 0.5840, 0.3549, 0.5951, 0.4851], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4049, 0.4069, 0.4252, 0.4342, 0.4849], grad_fn=<SigmoidBackward0>)
# tensor(0.2838, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2091, 0.5840, 0.3549, 0.5951, 0.4851])
# Curr pol
# tensor([0.2071, 0.5828, 0.3551, 0.5956, 0.4849])
# Iter:
# 19
# Inner prox iters used: 15
# Policy 1
# tensor([0.2071, 0.5828, 0.3551, 0.5956, 0.4849], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4059, 0.4072, 0.4259, 0.4345, 0.4850], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2071, 0.5828, 0.3551, 0.5956, 0.4849], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4059, 0.4072, 0.4259, 0.4345, 0.4850], grad_fn=<SigmoidBackward0>)
# tensor(0.2870, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2071, 0.5828, 0.3551, 0.5956, 0.4849])
# Curr pol
# tensor([0.2055, 0.5817, 0.3552, 0.5961, 0.4846])
# Iter:
# 20
# Inner prox iters used: 27
# Policy 1
# tensor([0.2055, 0.5817, 0.3552, 0.5961, 0.4846], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4073, 0.4077, 0.4269, 0.4350, 0.4852], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2055, 0.5817, 0.3552, 0.5961, 0.4846], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4073, 0.4077, 0.4269, 0.4350, 0.4852], grad_fn=<SigmoidBackward0>)
# tensor(0.2896, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2055, 0.5817, 0.3552, 0.5961, 0.4846])
# Curr pol
# tensor([0.2041, 0.5806, 0.3554, 0.5964, 0.4844])
# Iter:
# 21
# Inner prox iters used: 5
# Policy 1
# tensor([0.2041, 0.5806, 0.3554, 0.5964, 0.4844], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4076, 0.4078, 0.4271, 0.4351, 0.4852], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2041, 0.5806, 0.3554, 0.5964, 0.4844], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4076, 0.4078, 0.4271, 0.4351, 0.4852], grad_fn=<SigmoidBackward0>)
# tensor(0.2918, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2041, 0.5806, 0.3554, 0.5964, 0.4844])
# Curr pol
# tensor([0.2029, 0.5796, 0.3556, 0.5967, 0.4842])
# Iter:
# 22
# Inner prox iters used: 21
# Policy 1
# tensor([0.2029, 0.5796, 0.3556, 0.5967, 0.4842], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4086, 0.4081, 0.4278, 0.4354, 0.4853], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2029, 0.5796, 0.3556, 0.5967, 0.4842], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4086, 0.4081, 0.4278, 0.4354, 0.4853], grad_fn=<SigmoidBackward0>)
# tensor(0.2937, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2029, 0.5796, 0.3556, 0.5967, 0.4842])
# Curr pol
# tensor([0.2019, 0.5787, 0.3558, 0.5970, 0.4840])
# Iter:
# 23
# Inner prox iters used: 11
# Policy 1
# tensor([0.2019, 0.5787, 0.3558, 0.5970, 0.4840], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4090, 0.4082, 0.4281, 0.4356, 0.4853], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2019, 0.5787, 0.3558, 0.5970, 0.4840], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4090, 0.4082, 0.4281, 0.4356, 0.4853], grad_fn=<SigmoidBackward0>)
# tensor(0.2953, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2019, 0.5787, 0.3558, 0.5970, 0.4840])
# Curr pol
# tensor([0.2010, 0.5779, 0.3560, 0.5972, 0.4839])
# Iter:
# 24
# Inner prox iters used: 6
# Policy 1
# tensor([0.2010, 0.5779, 0.3560, 0.5972, 0.4839], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4093, 0.4083, 0.4283, 0.4357, 0.4853], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2010, 0.5779, 0.3560, 0.5972, 0.4839], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4093, 0.4083, 0.4283, 0.4357, 0.4853], grad_fn=<SigmoidBackward0>)
# tensor(0.2966, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2010, 0.5779, 0.3560, 0.5972, 0.4839])
# Curr pol
# tensor([0.2002, 0.5772, 0.3562, 0.5974, 0.4837])
# Iter:
# 25
# Inner prox iters used: 12
# Policy 1
# tensor([0.2002, 0.5772, 0.3562, 0.5974, 0.4837], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4097, 0.4085, 0.4286, 0.4358, 0.4854], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2002, 0.5772, 0.3562, 0.5974, 0.4837], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4097, 0.4085, 0.4286, 0.4358, 0.4854], grad_fn=<SigmoidBackward0>)
# tensor(0.2978, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2002, 0.5772, 0.3562, 0.5974, 0.4837])
# Curr pol
# tensor([0.1996, 0.5765, 0.3564, 0.5976, 0.4836])
# Iter:
# 26
# Inner prox iters used: 9
# Policy 1
# tensor([0.1996, 0.5765, 0.3564, 0.5976, 0.4836], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4100, 0.4086, 0.4288, 0.4360, 0.4854], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1996, 0.5765, 0.3564, 0.5976, 0.4836], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4100, 0.4086, 0.4288, 0.4360, 0.4854], grad_fn=<SigmoidBackward0>)
# tensor(0.2987, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1996, 0.5765, 0.3564, 0.5976, 0.4836])
# Curr pol
# tensor([0.1990, 0.5759, 0.3566, 0.5977, 0.4835])
# Iter:
# 27
# Inner prox iters used: 17
# Policy 1
# tensor([0.1990, 0.5759, 0.3566, 0.5977, 0.4835], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4105, 0.4087, 0.4292, 0.4361, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1990, 0.5759, 0.3566, 0.5977, 0.4835], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4105, 0.4087, 0.4292, 0.4361, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0.2996, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1990, 0.5759, 0.3566, 0.5977, 0.4835])
# Curr pol
# tensor([0.1985, 0.5754, 0.3568, 0.5978, 0.4834])
# Iter:
# 28
# Inner prox iters used: 6
# Policy 1
# tensor([0.1985, 0.5754, 0.3568, 0.5978, 0.4834], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4106, 0.4088, 0.4292, 0.4362, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1985, 0.5754, 0.3568, 0.5978, 0.4834], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4106, 0.4088, 0.4292, 0.4362, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0.3003, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1985, 0.5754, 0.3568, 0.5978, 0.4834])
# Curr pol
# tensor([0.1981, 0.5749, 0.3569, 0.5979, 0.4833])
# Iter:
# 29
# Inner prox iters used: 12
# Policy 1
# tensor([0.1981, 0.5749, 0.3569, 0.5979, 0.4833], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4108, 0.4088, 0.4294, 0.4362, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1981, 0.5749, 0.3569, 0.5979, 0.4833], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4108, 0.4088, 0.4294, 0.4362, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0.3009, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1981, 0.5749, 0.3569, 0.5979, 0.4833])
# Curr pol
# tensor([0.1978, 0.5745, 0.3571, 0.5980, 0.4832])
# Iter:
# 30
# Inner prox iters used: 15
# Policy 1
# tensor([0.1978, 0.5745, 0.3571, 0.5980, 0.4832], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4111, 0.4089, 0.4296, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1978, 0.5745, 0.3571, 0.5980, 0.4832], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4111, 0.4089, 0.4296, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0.3014, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1978, 0.5745, 0.3571, 0.5980, 0.4832])
# Curr pol
# tensor([0.1975, 0.5741, 0.3572, 0.5981, 0.4832])
# Iter:
# 31
# Inner prox iters used: 2
# Policy 1
# tensor([0.1975, 0.5741, 0.3572, 0.5981, 0.4832], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4111, 0.4089, 0.4296, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1975, 0.5741, 0.3572, 0.5981, 0.4832], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4111, 0.4089, 0.4296, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0.3018, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1975, 0.5741, 0.3572, 0.5981, 0.4832])
# Curr pol
# tensor([0.1972, 0.5738, 0.3573, 0.5982, 0.4831])
# Iter:
# 32
# Inner prox iters used: 11
# Policy 1
# tensor([0.1972, 0.5738, 0.3573, 0.5982, 0.4831], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4112, 0.4089, 0.4297, 0.4364, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1972, 0.5738, 0.3573, 0.5982, 0.4831], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4112, 0.4089, 0.4297, 0.4364, 0.4855], grad_fn=<SigmoidBackward0>)
# tensor(0.3022, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1972, 0.5738, 0.3573, 0.5982, 0.4831])
# Curr pol
# tensor([0.1969, 0.5735, 0.3574, 0.5982, 0.4831])
# Iter:
# 33
# Inner prox iters used: 12
# Policy 1
# tensor([0.1969, 0.5735, 0.3574, 0.5982, 0.4831], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4114, 0.4090, 0.4298, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1969, 0.5735, 0.3574, 0.5982, 0.4831], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4114, 0.4090, 0.4298, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3025, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1969, 0.5735, 0.3574, 0.5982, 0.4831])
# Curr pol
# tensor([0.1967, 0.5732, 0.3575, 0.5983, 0.4830])
# Iter:
# 34
# Inner prox iters used: 6
# Policy 1
# tensor([0.1967, 0.5732, 0.3575, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4114, 0.4090, 0.4298, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1967, 0.5732, 0.3575, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4114, 0.4090, 0.4298, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3028, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1967, 0.5732, 0.3575, 0.5983, 0.4830])
# Curr pol
# tensor([0.1965, 0.5730, 0.3576, 0.5983, 0.4830])
# Iter:
# 35
# Inner prox iters used: 10
# Policy 1
# tensor([0.1965, 0.5730, 0.3576, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4115, 0.4090, 0.4299, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1965, 0.5730, 0.3576, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4115, 0.4090, 0.4299, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3031, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1965, 0.5730, 0.3576, 0.5983, 0.4830])
# Curr pol
# tensor([0.1964, 0.5728, 0.3577, 0.5984, 0.4829])
# Iter:
# 36
# Inner prox iters used: 11
# Policy 1
# tensor([0.1964, 0.5728, 0.3577, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4116, 0.4090, 0.4299, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1964, 0.5728, 0.3577, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4116, 0.4090, 0.4299, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3033, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1964, 0.5728, 0.3577, 0.5984, 0.4829])
# Curr pol
# tensor([0.1962, 0.5727, 0.3578, 0.5984, 0.4829])
# Iter:
# 37
# Inner prox iters used: 1
# Policy 1
# tensor([0.1962, 0.5727, 0.3578, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4116, 0.4091, 0.4300, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1962, 0.5727, 0.3578, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4116, 0.4091, 0.4300, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3035, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1962, 0.5727, 0.3578, 0.5984, 0.4829])
# Curr pol
# tensor([0.1961, 0.5725, 0.3578, 0.5984, 0.4829])
# Iter:
# 38
# Inner prox iters used: 2
# Policy 1
# tensor([0.1961, 0.5725, 0.3578, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4116, 0.4091, 0.4300, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1961, 0.5725, 0.3578, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4116, 0.4091, 0.4300, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3036, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.5725, 0.3578, 0.5984, 0.4829])
# Curr pol
# tensor([0.1960, 0.5724, 0.3579, 0.5984, 0.4828])
# Iter:
# 39
# Inner prox iters used: 6
# Policy 1
# tensor([0.1960, 0.5724, 0.3579, 0.5984, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4117, 0.4091, 0.4300, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1960, 0.5724, 0.3579, 0.5984, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4117, 0.4091, 0.4300, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3038, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1960, 0.5724, 0.3579, 0.5984, 0.4828])
# Curr pol
# tensor([0.1959, 0.5723, 0.3579, 0.5985, 0.4828])
# Iter:
# 40
# Inner prox iters used: 11
# Policy 1
# tensor([0.1959, 0.5723, 0.3579, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4117, 0.4091, 0.4300, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1959, 0.5723, 0.3579, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4117, 0.4091, 0.4300, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3039, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1959, 0.5723, 0.3579, 0.5985, 0.4828])
# Curr pol
# tensor([0.1958, 0.5722, 0.3580, 0.5985, 0.4828])
# Iter:
# 41
# Inner prox iters used: 7
# Policy 1
# tensor([0.1958, 0.5722, 0.3580, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4118, 0.4091, 0.4301, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1958, 0.5722, 0.3580, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4118, 0.4091, 0.4301, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1958, 0.5722, 0.3580, 0.5985, 0.4828])
# Curr pol
# tensor([0.1958, 0.5721, 0.3580, 0.5985, 0.4828])
# Iter:
# 42
# Inner prox iters used: 21
# Policy 1
# tensor([0.1958, 0.5721, 0.3580, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4118, 0.4091, 0.4301, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1958, 0.5721, 0.3580, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4118, 0.4091, 0.4301, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1958, 0.5721, 0.3580, 0.5985, 0.4828])
# Curr pol
# tensor([0.1957, 0.5720, 0.3581, 0.5985, 0.4828])
# Iter:
# 43
# Inner prox iters used: 21
# Policy 1
# tensor([0.1957, 0.5720, 0.3581, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4301, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1957, 0.5720, 0.3581, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4301, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3042, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1957, 0.5720, 0.3581, 0.5985, 0.4828])
# Curr pol
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827])
# Iter:
# 44
# Inner prox iters used: 8
# Policy 1
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3043, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827])
# Curr pol
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827])
# Iter:
# 45
# Inner prox iters used: 2
# Policy 1
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3043, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1956, 0.5719, 0.3581, 0.5985, 0.4827])
# Curr pol
# tensor([0.1956, 0.5718, 0.3582, 0.5986, 0.4827])
# Iter:
# 46
# Inner prox iters used: 4
# Policy 1
# tensor([0.1956, 0.5718, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1956, 0.5718, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3044, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1956, 0.5718, 0.3582, 0.5986, 0.4827])
# Curr pol
# tensor([0.1955, 0.5718, 0.3582, 0.5986, 0.4827])
# Iter:
# 47
# Inner prox iters used: 43
# Policy 1
# tensor([0.1955, 0.5718, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1955, 0.5718, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3044, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1955, 0.5718, 0.3582, 0.5986, 0.4827])
# Curr pol
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827])
# Iter:
# 48
# Inner prox iters used: 11
# Policy 1
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3045, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827])
# Curr pol
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827])
# Iter:
# 49
# Inner prox iters used: 1
# Policy 1
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4119, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3045, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1955, 0.5717, 0.3582, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.5716, 0.3582, 0.5986, 0.4827])
# Iter:
# 50
# Inner prox iters used: 13
# Policy 1
# tensor([0.1954, 0.5716, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4120, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1954, 0.5716, 0.3582, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4120, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3045, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.5716, 0.3582, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827])
# Iter:
# 51
# Inner prox iters used: 10
# Policy 1
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4120, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4120, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3046, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827])
# Iter:
# 52
# Inner prox iters used: 8
# Policy 1
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4120, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4120, 0.4091, 0.4302, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# tensor(0.3046, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827])
# Iter:
# 53
# Outer prox iters used: 53
# Inner prox iters used: 145
# Policy 1
# tensor([0.2106, 0.2106, 0.3605, 0.3605, 0.4517], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2106, 0.2106, 0.3605, 0.3605, 0.4517], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.5000, 0.5000, 0.5000, 0.5000, 0.5000])
# Curr pol
# tensor([0.4627, 0.4627, 0.5123, 0.5123, 0.4979])
# Iter:
# 1
# Inner prox iters used: 94
# Policy 1
# tensor([0.2233, 0.2379, 0.3623, 0.3704, 0.4566], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4627, 0.4627, 0.5123, 0.5123, 0.4979], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2233, 0.2379, 0.3623, 0.3704, 0.4566], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4627, 0.4627, 0.5123, 0.5123, 0.4979], grad_fn=<SigmoidBackward0>)
# tensor(0.0062, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.4627, 0.4627, 0.5123, 0.5123, 0.4979])
# Curr pol
# tensor([0.4272, 0.4338, 0.5245, 0.5237, 0.4962])
# Iter:
# 2
# Inner prox iters used: 98
# Policy 1
# tensor([0.2384, 0.2651, 0.3650, 0.3793, 0.4612], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4272, 0.4338, 0.5245, 0.5237, 0.4962], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2384, 0.2651, 0.3650, 0.3793, 0.4612], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.4272, 0.4338, 0.5245, 0.5237, 0.4962], grad_fn=<SigmoidBackward0>)
# tensor(0.0219, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.4272, 0.4338, 0.5245, 0.5237, 0.4962])
# Curr pol
# tensor([0.3941, 0.4118, 0.5365, 0.5344, 0.4947])
# Iter:
# 3
# Inner prox iters used: 75
# Policy 1
# tensor([0.2546, 0.2901, 0.3688, 0.3877, 0.4652], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3941, 0.4118, 0.5365, 0.5344, 0.4947], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2546, 0.2901, 0.3688, 0.3877, 0.4652], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3941, 0.4118, 0.5365, 0.5344, 0.4947], grad_fn=<SigmoidBackward0>)
# tensor(0.0438, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3941, 0.4118, 0.5365, 0.5344, 0.4947])
# Curr pol
# tensor([0.3639, 0.3954, 0.5479, 0.5442, 0.4934])
# Iter:
# 4
# Inner prox iters used: 81
# Policy 1
# tensor([0.2729, 0.3141, 0.3730, 0.3952, 0.4688], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3639, 0.3954, 0.5479, 0.5442, 0.4934], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2729, 0.3141, 0.3730, 0.3952, 0.4688], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3639, 0.3954, 0.5479, 0.5442, 0.4934], grad_fn=<SigmoidBackward0>)
# tensor(0.0695, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3639, 0.3954, 0.5479, 0.5442, 0.4934])
# Curr pol
# tensor([0.3368, 0.3833, 0.5584, 0.5532, 0.4924])
# Iter:
# 5
# Inner prox iters used: 94
# Policy 1
# tensor([0.2924, 0.3359, 0.3776, 0.4020, 0.4720], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3368, 0.3833, 0.5584, 0.5532, 0.4924], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.2924, 0.3359, 0.3776, 0.4020, 0.4720], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3368, 0.3833, 0.5584, 0.5532, 0.4924], grad_fn=<SigmoidBackward0>)
# tensor(0.0970, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3368, 0.3833, 0.5584, 0.5532, 0.4924])
# Curr pol
# tensor([0.3130, 0.3746, 0.5677, 0.5612, 0.4914])
# Iter:
# 6
# Inner prox iters used: 74
# Policy 1
# tensor([0.3110, 0.3543, 0.3824, 0.4081, 0.4747], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3130, 0.3746, 0.5677, 0.5612, 0.4914], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3110, 0.3543, 0.3824, 0.4081, 0.4747], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.3130, 0.3746, 0.5677, 0.5612, 0.4914], grad_fn=<SigmoidBackward0>)
# tensor(0.1248, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.3130, 0.3746, 0.5677, 0.5612, 0.4914])
# Curr pol
# tensor([0.2926, 0.3683, 0.5754, 0.5682, 0.4906])
# Iter:
# 7
# Inner prox iters used: 107
# Policy 1
# tensor([0.3300, 0.3708, 0.3868, 0.4133, 0.4771], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2926, 0.3683, 0.5754, 0.5682, 0.4906], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3300, 0.3708, 0.3868, 0.4133, 0.4771], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2926, 0.3683, 0.5754, 0.5682, 0.4906], grad_fn=<SigmoidBackward0>)
# tensor(0.1515, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2926, 0.3683, 0.5754, 0.5682, 0.4906])
# Curr pol
# tensor([0.2754, 0.3638, 0.5813, 0.5740, 0.4899])
# Iter:
# 8
# Inner prox iters used: 70
# Policy 1
# tensor([0.3455, 0.3834, 0.3909, 0.4178, 0.4789], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2754, 0.3638, 0.5813, 0.5740, 0.4899], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3455, 0.3834, 0.3909, 0.4178, 0.4789], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2754, 0.3638, 0.5813, 0.5740, 0.4899], grad_fn=<SigmoidBackward0>)
# tensor(0.1759, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2754, 0.3638, 0.5813, 0.5740, 0.4899])
# Curr pol
# tensor([0.2612, 0.3607, 0.5855, 0.5788, 0.4892])
# Iter:
# 9
# Inner prox iters used: 92
# Policy 1
# tensor([0.3600, 0.3941, 0.3943, 0.4215, 0.4804], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2612, 0.3607, 0.5855, 0.5788, 0.4892], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3600, 0.3941, 0.3943, 0.4215, 0.4804], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2612, 0.3607, 0.5855, 0.5788, 0.4892], grad_fn=<SigmoidBackward0>)
# tensor(0.1975, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2612, 0.3607, 0.5855, 0.5788, 0.4892])
# Curr pol
# tensor([0.2496, 0.3586, 0.5881, 0.5827, 0.4886])
# Iter:
# 10
# Inner prox iters used: 58
# Policy 1
# tensor([0.3705, 0.4017, 0.3972, 0.4245, 0.4815], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2496, 0.3586, 0.5881, 0.5827, 0.4886], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3705, 0.4017, 0.3972, 0.4245, 0.4815], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2496, 0.3586, 0.5881, 0.5827, 0.4886], grad_fn=<SigmoidBackward0>)
# tensor(0.2159, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2496, 0.3586, 0.5881, 0.5827, 0.4886])
# Curr pol
# tensor([0.2403, 0.3571, 0.5895, 0.5857, 0.4880])
# Iter:
# 11
# Inner prox iters used: 62
# Policy 1
# tensor([0.3797, 0.4081, 0.3996, 0.4269, 0.4824], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2403, 0.3571, 0.5895, 0.5857, 0.4880], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3797, 0.4081, 0.3996, 0.4269, 0.4824], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2403, 0.3571, 0.5895, 0.5857, 0.4880], grad_fn=<SigmoidBackward0>)
# tensor(0.2314, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2403, 0.3571, 0.5895, 0.5857, 0.4880])
# Curr pol
# tensor([0.2327, 0.3561, 0.5899, 0.5881, 0.4875])
# Iter:
# 12
# Inner prox iters used: 48
# Policy 1
# tensor([0.3864, 0.4127, 0.4015, 0.4288, 0.4831], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2327, 0.3561, 0.5899, 0.5881, 0.4875], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3864, 0.4127, 0.4015, 0.4288, 0.4831], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2327, 0.3561, 0.5899, 0.5881, 0.4875], grad_fn=<SigmoidBackward0>)
# tensor(0.2440, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2327, 0.3561, 0.5899, 0.5881, 0.4875])
# Curr pol
# tensor([0.2266, 0.3555, 0.5896, 0.5900, 0.4870])
# Iter:
# 13
# Inner prox iters used: 40
# Policy 1
# tensor([0.3917, 0.4163, 0.4030, 0.4303, 0.4836], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2266, 0.3555, 0.5896, 0.5900, 0.4870], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3917, 0.4163, 0.4030, 0.4303, 0.4836], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2266, 0.3555, 0.5896, 0.5900, 0.4870], grad_fn=<SigmoidBackward0>)
# tensor(0.2544, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2266, 0.3555, 0.5896, 0.5900, 0.4870])
# Curr pol
# tensor([0.2216, 0.3551, 0.5889, 0.5915, 0.4865])
# Iter:
# 14
# Inner prox iters used: 44
# Policy 1
# tensor([0.3962, 0.4193, 0.4042, 0.4315, 0.4841], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2216, 0.3551, 0.5889, 0.5915, 0.4865], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3962, 0.4193, 0.4042, 0.4315, 0.4841], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2216, 0.3551, 0.5889, 0.5915, 0.4865], grad_fn=<SigmoidBackward0>)
# tensor(0.2629, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2216, 0.3551, 0.5889, 0.5915, 0.4865])
# Curr pol
# tensor([0.2175, 0.3549, 0.5878, 0.5927, 0.4861])
# Iter:
# 15
# Inner prox iters used: 36
# Policy 1
# tensor([0.3993, 0.4214, 0.4051, 0.4324, 0.4844], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2175, 0.3549, 0.5878, 0.5927, 0.4861], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.3993, 0.4214, 0.4051, 0.4324, 0.4844], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2175, 0.3549, 0.5878, 0.5927, 0.4861], grad_fn=<SigmoidBackward0>)
# tensor(0.2697, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2175, 0.3549, 0.5878, 0.5927, 0.4861])
# Curr pol
# tensor([0.2142, 0.3548, 0.5866, 0.5937, 0.4858])
# Iter:
# 16
# Inner prox iters used: 44
# Policy 1
# tensor([0.4021, 0.4232, 0.4059, 0.4332, 0.4846], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2142, 0.3548, 0.5866, 0.5937, 0.4858], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4021, 0.4232, 0.4059, 0.4332, 0.4846], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2142, 0.3548, 0.5866, 0.5937, 0.4858], grad_fn=<SigmoidBackward0>)
# tensor(0.2754, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2142, 0.3548, 0.5866, 0.5937, 0.4858])
# Curr pol
# tensor([0.2114, 0.3548, 0.5853, 0.5945, 0.4854])
# Iter:
# 17
# Inner prox iters used: 23
# Policy 1
# tensor([0.4036, 0.4243, 0.4064, 0.4337, 0.4848], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2114, 0.3548, 0.5853, 0.5945, 0.4854], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4036, 0.4243, 0.4064, 0.4337, 0.4848], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2114, 0.3548, 0.5853, 0.5945, 0.4854], grad_fn=<SigmoidBackward0>)
# tensor(0.2799, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2114, 0.3548, 0.5853, 0.5945, 0.4854])
# Curr pol
# tensor([0.2091, 0.3549, 0.5840, 0.5951, 0.4851])
# Iter:
# 18
# Inner prox iters used: 27
# Policy 1
# tensor([0.4052, 0.4254, 0.4070, 0.4342, 0.4849], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2091, 0.3549, 0.5840, 0.5951, 0.4851], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4052, 0.4254, 0.4070, 0.4342, 0.4849], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2091, 0.3549, 0.5840, 0.5951, 0.4851], grad_fn=<SigmoidBackward0>)
# tensor(0.2838, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2091, 0.3549, 0.5840, 0.5951, 0.4851])
# Curr pol
# tensor([0.2072, 0.3551, 0.5828, 0.5956, 0.4849])
# Iter:
# 19
# Inner prox iters used: 25
# Policy 1
# tensor([0.4064, 0.4262, 0.4073, 0.4346, 0.4851], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2072, 0.3551, 0.5828, 0.5956, 0.4849], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4064, 0.4262, 0.4073, 0.4346, 0.4851], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2072, 0.3551, 0.5828, 0.5956, 0.4849], grad_fn=<SigmoidBackward0>)
# tensor(0.2869, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2072, 0.3551, 0.5828, 0.5956, 0.4849])
# Curr pol
# tensor([0.2055, 0.3552, 0.5816, 0.5960, 0.4846])
# Iter:
# 20
# Inner prox iters used: 29
# Policy 1
# tensor([0.4075, 0.4270, 0.4077, 0.4350, 0.4852], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2055, 0.3552, 0.5816, 0.5960, 0.4846], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4075, 0.4270, 0.4077, 0.4350, 0.4852], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2055, 0.3552, 0.5816, 0.5960, 0.4846], grad_fn=<SigmoidBackward0>)
# tensor(0.2896, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2055, 0.3552, 0.5816, 0.5960, 0.4846])
# Curr pol
# tensor([0.2041, 0.3554, 0.5805, 0.5964, 0.4844])
# Iter:
# 21
# Inner prox iters used: 40
# Policy 1
# tensor([0.4084, 0.4276, 0.4080, 0.4353, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2041, 0.3554, 0.5805, 0.5964, 0.4844], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4084, 0.4276, 0.4080, 0.4353, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2041, 0.3554, 0.5805, 0.5964, 0.4844], grad_fn=<SigmoidBackward0>)
# tensor(0.2918, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2041, 0.3554, 0.5805, 0.5964, 0.4844])
# Curr pol
# tensor([0.2029, 0.3556, 0.5795, 0.5967, 0.4842])
# Iter:
# 22
# Inner prox iters used: 17
# Policy 1
# tensor([0.4088, 0.4279, 0.4081, 0.4354, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2029, 0.3556, 0.5795, 0.5967, 0.4842], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4088, 0.4279, 0.4081, 0.4354, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2029, 0.3556, 0.5795, 0.5967, 0.4842], grad_fn=<SigmoidBackward0>)
# tensor(0.2936, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2029, 0.3556, 0.5795, 0.5967, 0.4842])
# Curr pol
# tensor([0.2019, 0.3558, 0.5786, 0.5970, 0.4840])
# Iter:
# 23
# Inner prox iters used: 12
# Policy 1
# tensor([0.4091, 0.4282, 0.4082, 0.4356, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2019, 0.3558, 0.5786, 0.5970, 0.4840], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4091, 0.4282, 0.4082, 0.4356, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2019, 0.3558, 0.5786, 0.5970, 0.4840], grad_fn=<SigmoidBackward0>)
# tensor(0.2951, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2019, 0.3558, 0.5786, 0.5970, 0.4840])
# Curr pol
# tensor([0.2011, 0.3560, 0.5778, 0.5972, 0.4839])
# Iter:
# 24
# Inner prox iters used: 2
# Policy 1
# tensor([0.4092, 0.4282, 0.4083, 0.4356, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2011, 0.3560, 0.5778, 0.5972, 0.4839], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4092, 0.4282, 0.4083, 0.4356, 0.4853], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2011, 0.3560, 0.5778, 0.5972, 0.4839], grad_fn=<SigmoidBackward0>)
# tensor(0.2965, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2011, 0.3560, 0.5778, 0.5972, 0.4839])
# Curr pol
# tensor([0.2003, 0.3562, 0.5771, 0.5974, 0.4837])
# Iter:
# 25
# Inner prox iters used: 38
# Policy 1
# tensor([0.4101, 0.4289, 0.4086, 0.4359, 0.4854], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2003, 0.3562, 0.5771, 0.5974, 0.4837], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4101, 0.4289, 0.4086, 0.4359, 0.4854], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.2003, 0.3562, 0.5771, 0.5974, 0.4837], grad_fn=<SigmoidBackward0>)
# tensor(0.2977, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.2003, 0.3562, 0.5771, 0.5974, 0.4837])
# Curr pol
# tensor([0.1996, 0.3564, 0.5764, 0.5975, 0.4836])
# Iter:
# 26
# Inner prox iters used: 8
# Policy 1
# tensor([0.4103, 0.4290, 0.4086, 0.4360, 0.4854], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1996, 0.3564, 0.5764, 0.5975, 0.4836], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4103, 0.4290, 0.4086, 0.4360, 0.4854], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1996, 0.3564, 0.5764, 0.5975, 0.4836], grad_fn=<SigmoidBackward0>)
# tensor(0.2986, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1996, 0.3564, 0.5764, 0.5975, 0.4836])
# Curr pol
# tensor([0.1991, 0.3566, 0.5758, 0.5977, 0.4835])
# Iter:
# 27
# Inner prox iters used: 8
# Policy 1
# tensor([0.4104, 0.4291, 0.4087, 0.4361, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1991, 0.3566, 0.5758, 0.5977, 0.4835], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4104, 0.4291, 0.4087, 0.4361, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1991, 0.3566, 0.5758, 0.5977, 0.4835], grad_fn=<SigmoidBackward0>)
# tensor(0.2994, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1991, 0.3566, 0.5758, 0.5977, 0.4835])
# Curr pol
# tensor([0.1986, 0.3567, 0.5753, 0.5978, 0.4834])
# Iter:
# 28
# Inner prox iters used: 8
# Policy 1
# tensor([0.4106, 0.4292, 0.4087, 0.4361, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1986, 0.3567, 0.5753, 0.5978, 0.4834], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4106, 0.4292, 0.4087, 0.4361, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1986, 0.3567, 0.5753, 0.5978, 0.4834], grad_fn=<SigmoidBackward0>)
# tensor(0.3002, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1986, 0.3567, 0.5753, 0.5978, 0.4834])
# Curr pol
# tensor([0.1982, 0.3569, 0.5749, 0.5979, 0.4833])
# Iter:
# 29
# Inner prox iters used: 43
# Policy 1
# tensor([0.4110, 0.4296, 0.4089, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1982, 0.3569, 0.5749, 0.5979, 0.4833], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4110, 0.4296, 0.4089, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1982, 0.3569, 0.5749, 0.5979, 0.4833], grad_fn=<SigmoidBackward0>)
# tensor(0.3008, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1982, 0.3569, 0.5749, 0.5979, 0.4833])
# Curr pol
# tensor([0.1978, 0.3570, 0.5744, 0.5980, 0.4832])
# Iter:
# 30
# Inner prox iters used: 12
# Policy 1
# tensor([0.4111, 0.4296, 0.4089, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1978, 0.3570, 0.5744, 0.5980, 0.4832], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4111, 0.4296, 0.4089, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# ...
# tensor([0.4111, 0.4296, 0.4089, 0.4363, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1975, 0.3572, 0.5741, 0.5981, 0.4832], grad_fn=<SigmoidBackward0>)
# tensor(0.3017, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1975, 0.3572, 0.5741, 0.5981, 0.4832])
# Curr pol
# tensor([0.1972, 0.3573, 0.5738, 0.5981, 0.4831])
# Iter:
# 32
# Inner prox iters used: 7
# Policy 1
# tensor([0.4112, 0.4297, 0.4089, 0.4364, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1972, 0.3573, 0.5738, 0.5981, 0.4831], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4112, 0.4297, 0.4089, 0.4364, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1972, 0.3573, 0.5738, 0.5981, 0.4831], grad_fn=<SigmoidBackward0>)
# tensor(0.3021, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1972, 0.3573, 0.5738, 0.5981, 0.4831])
# Curr pol
# tensor([0.1970, 0.3574, 0.5735, 0.5982, 0.4831])
# Iter:
# 33
# Inner prox iters used: 9
# Policy 1
# tensor([0.4113, 0.4298, 0.4090, 0.4364, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1970, 0.3574, 0.5735, 0.5982, 0.4831], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4113, 0.4298, 0.4090, 0.4364, 0.4855], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1970, 0.3574, 0.5735, 0.5982, 0.4831], grad_fn=<SigmoidBackward0>)
# tensor(0.3025, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1970, 0.3574, 0.5735, 0.5982, 0.4831])
# Curr pol
# tensor([0.1967, 0.3575, 0.5732, 0.5983, 0.4830])
# Iter:
# 34
# Inner prox iters used: 6
# Policy 1
# tensor([0.4114, 0.4298, 0.4090, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1967, 0.3575, 0.5732, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4114, 0.4298, 0.4090, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1967, 0.3575, 0.5732, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# tensor(0.3028, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1967, 0.3575, 0.5732, 0.5983, 0.4830])
# Curr pol
# tensor([0.1966, 0.3576, 0.5730, 0.5983, 0.4830])
# Iter:
# 35
# Inner prox iters used: 1
# Policy 1
# tensor([0.4114, 0.4298, 0.4090, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1966, 0.3576, 0.5730, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4114, 0.4298, 0.4090, 0.4364, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1966, 0.3576, 0.5730, 0.5983, 0.4830], grad_fn=<SigmoidBackward0>)
# tensor(0.3030, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1966, 0.3576, 0.5730, 0.5983, 0.4830])
# Curr pol
# tensor([0.1964, 0.3577, 0.5728, 0.5983, 0.4829])
# Iter:
# 36
# Inner prox iters used: 12
# Policy 1
# tensor([0.4115, 0.4299, 0.4090, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1964, 0.3577, 0.5728, 0.5983, 0.4829], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4115, 0.4299, 0.4090, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1964, 0.3577, 0.5728, 0.5983, 0.4829], grad_fn=<SigmoidBackward0>)
# tensor(0.3033, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1964, 0.3577, 0.5728, 0.5983, 0.4829])
# Curr pol
# tensor([0.1962, 0.3578, 0.5727, 0.5984, 0.4829])
# Iter:
# 37
# Inner prox iters used: 18
# Policy 1
# tensor([0.4116, 0.4300, 0.4091, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1962, 0.3578, 0.5727, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4116, 0.4300, 0.4091, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1962, 0.3578, 0.5727, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# tensor(0.3035, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1962, 0.3578, 0.5727, 0.5984, 0.4829])
# Curr pol
# tensor([0.1961, 0.3578, 0.5725, 0.5984, 0.4829])
# Iter:
# 38
# Inner prox iters used: 2
# Policy 1
# tensor([0.4117, 0.4300, 0.4091, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1961, 0.3578, 0.5725, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4117, 0.4300, 0.4091, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1961, 0.3578, 0.5725, 0.5984, 0.4829], grad_fn=<SigmoidBackward0>)
# tensor(0.3036, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1961, 0.3578, 0.5725, 0.5984, 0.4829])
# Curr pol
# tensor([0.1960, 0.3579, 0.5724, 0.5984, 0.4828])
# Iter:
# 39
# Inner prox iters used: 1
# Policy 1
# tensor([0.4117, 0.4300, 0.4091, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1960, 0.3579, 0.5724, 0.5984, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4117, 0.4300, 0.4091, 0.4365, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1960, 0.3579, 0.5724, 0.5984, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0.3038, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1960, 0.3579, 0.5724, 0.5984, 0.4828])
# Curr pol
# tensor([0.1959, 0.3579, 0.5723, 0.5985, 0.4828])
# Iter:
# 40
# Inner prox iters used: 10
# Policy 1
# tensor([0.4117, 0.4300, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1959, 0.3579, 0.5723, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4117, 0.4300, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1959, 0.3579, 0.5723, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0.3039, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1959, 0.3579, 0.5723, 0.5985, 0.4828])
# Curr pol
# tensor([0.1958, 0.3580, 0.5722, 0.5985, 0.4828])
# Iter:
# 41
# Inner prox iters used: 21
# Policy 1
# tensor([0.4118, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1958, 0.3580, 0.5722, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4118, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1958, 0.3580, 0.5722, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0.3040, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1958, 0.3580, 0.5722, 0.5985, 0.4828])
# Curr pol
# tensor([0.1958, 0.3580, 0.5721, 0.5985, 0.4828])
# Iter:
# 42
# Inner prox iters used: 2
# Policy 1
# tensor([0.4118, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1958, 0.3580, 0.5721, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4118, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1958, 0.3580, 0.5721, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0.3041, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1958, 0.3580, 0.5721, 0.5985, 0.4828])
# Curr pol
# tensor([0.1957, 0.3581, 0.5720, 0.5985, 0.4828])
# Iter:
# 43
# Inner prox iters used: 10
# Policy 1
# tensor([0.4118, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1957, 0.3581, 0.5720, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4118, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1957, 0.3581, 0.5720, 0.5985, 0.4828], grad_fn=<SigmoidBackward0>)
# tensor(0.3042, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1957, 0.3581, 0.5720, 0.5985, 0.4828])
# Curr pol
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827])
# Iter:
# 44
# Inner prox iters used: 16
# Policy 1
# tensor([0.4119, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4301, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3043, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827])
# Curr pol
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827])
# Iter:
# 45
# Inner prox iters used: 4
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3043, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1956, 0.3581, 0.5719, 0.5985, 0.4827])
# Curr pol
# tensor([0.1956, 0.3582, 0.5718, 0.5986, 0.4827])
# Iter:
# 46
# Inner prox iters used: 29
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1956, 0.3582, 0.5718, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1956, 0.3582, 0.5718, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3044, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1956, 0.3582, 0.5718, 0.5986, 0.4827])
# Curr pol
# tensor([0.1955, 0.3582, 0.5718, 0.5986, 0.4827])
# Iter:
# 47
# Inner prox iters used: 8
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1955, 0.3582, 0.5718, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1955, 0.3582, 0.5718, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3044, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1955, 0.3582, 0.5718, 0.5986, 0.4827])
# Curr pol
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827])
# Iter:
# 48
# Inner prox iters used: 1
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3045, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827])
# Curr pol
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827])
# Iter:
# 49
# Inner prox iters used: 4
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3045, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1955, 0.3582, 0.5717, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.3582, 0.5716, 0.5986, 0.4827])
# Iter:
# 50
# Inner prox iters used: 8
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3582, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4119, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3582, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3045, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.3582, 0.5716, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827])
# Iter:
# 51
# Inner prox iters used: 4
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3046, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827])
# Iter:
# 52
# Inner prox iters used: 18
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3046, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827])
# Iter:
# 53
# Inner prox iters used: 8
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# tensor(0.3046, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4827])
# Curr pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4826])
# Iter:
# 54
# Inner prox iters used: 3
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0.3046, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1954, 0.3583, 0.5716, 0.5986, 0.4826])
# Curr pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Iter:
# 55
# Inner prox iters used: 12
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0.3047, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Curr pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Iter:
# 56
# Inner prox iters used: 4
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4091, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0.3047, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Curr pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Iter:
# 57
# Inner prox iters used: 21
# Policy 1
# tensor([0.4120, 0.4302, 0.4092, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4092, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0.3047, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Curr pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Iter:
# 58
# Inner prox iters used: 14
# Policy 1
# tensor([0.4120, 0.4302, 0.4092, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0., grad_fn=<DivBackward0>)
# Policy 1
# tensor([0.4120, 0.4302, 0.4092, 0.4366, 0.4856], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
# tensor(0.3047, grad_fn=<DivBackward0>)
# Prev pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Curr pol
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826])
# Iter:
# 59
# Outer prox iters used: 59
# Epoch: 1
# Time Elapsed: 57.3 seconds
# Discounted Rewards: tensor([3.1651, 3.1658])
# Max Avg Coop Payout (Infinite Horizon): 8.250
# Policy 1
# tensor([0.1954, 0.5716, 0.3583, 0.5986, 0.4827], grad_fn=<SigmoidBackward0>)
# Policy 2
# tensor([0.1953, 0.3583, 0.5715, 0.5986, 0.4826], grad_fn=<SigmoidBackward0>)
